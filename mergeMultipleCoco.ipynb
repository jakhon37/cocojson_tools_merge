# %% [markdown]
# # update image size / only single json image¶

# %%
import json

# local_path = './'
# local_path = './dataset/testData/valid/'
local_path = './DATA/testData/train/'
coco_json = 'road_train_json.json'

# coco_json = 'road_validate_json.json'
coco_json_file = local_path + coco_json

new_json_file = 'custom_json.json'

open(local_path + new_json_file, 'w').close()

class Json_line:


    def __init__(self, img, ant, ctg):
        # Get image info. Annotations are dealt with seperately

        ############## IMAGES
        images = []
        for img in img:
#             img = img

            image = {"file_name": img["file_name"], "id": img["id"], "width": 960,
                         "height": 540}
            images.append(image)
            print(f'file_name { img["file_name"] } ')

        ############## ANNOTATIONS
        annotations = []
        for ant_i in ant:

            for ant_i in ant:
                area = ant_i["area"]
                seg_list = ant_i["segmentation"][0]
#                 xcoords, ycoords = [], []
#                 for i in range(0, len(seg_list), 2):
#                     xcoords.append(seg_list[i])
#                 for i in range(1, len(seg_list), 2):
#                     ycoords.append(seg_list[i])
#                 xmax, ymin = float(max(xcoords)), float(min(ycoords))
#                 ymax, xmin = float(max(ycoords)), float(min(xcoords))
#                 # poly_bbox = [xmax, ymin, ymax, xmin]
#                 width, height = xmax - xmin, ymax - ymin
#                 bbox_values = xmin, ymin, width, height
                # print(f' bbox_values list {bbox_values}')

                annotation = {"segmentation": ant_i["segmentation"], "image_id": ant_i["image_id"],
                              # "polyline": ant["polyline"],
                              "bbox": ant_i["bbox"], "category_id": ant_i["category_id"], "area": ant_i["area"],
                              "iscrowd": ant_i["is_crowd"], "id": ant_i["id"]}
                annotations.append(annotation)

        ############## CATEGORIES
        categories = []
        for ctg_i in ctg:
            category = {"id": ctg_i["id"], "name": ctg_i["name"],
                        # "polyline": ctg["polyline"],
                        # "id": ctg["id"]
                        # "supercategory": ctg["supercategory"], "color": ctg["color"], "metadata": ctg["metadata"],
                        # "keypoint_colors": ctg["keypoint_colors"]
                        }
            categories.append(category)

        self.__dict__['images'] = images
        self.__dict__["annotations"] = annotations
        self.__dict__["categories"] = categories    # categories


# open source json annotation file and print number of objects
with open(coco_json_file) as f:
    js = json.load(f)
    source_images = js['images']
    source_categories = js['categories']
    source_annotations = js['annotations']
    # print(source_annotations)
    # i_s = source_annotations[3]
    # i_seg = i_s['segmentation'][0]
    # print(i_seg)

    print('images: ' + str(len(source_images)))
    print('annotations: ' + str(len(source_annotations)))
    print('categories: ' + str(len(source_categories)))

# get source objects and feed them into class Json_line to process
im = Json_line(source_images, source_annotations, source_categories)

print('Writing Custom Labels manifest...')
# write new json file with new format
with open(local_path + new_json_file, 'a+') as outfile:
    # print(f' OUTFILE: ==== {outfile}')
    json.dump(im.__dict__, outfile, sort_keys=True, indent=4)
    outfile.write('\n')
    outfile.close()

print(f' Outfile: == {new_json_file} // Location: == {local_path}')
# Out:
# images: 85
# annotations: 3279
# categories: 3
# file_name 201213_E_16_CCW_in_E_B_002_00618.png
# file_name 201213_E_16_CCW_in_E_B_003_02364.png
# file_name 201213_E_16_CCW_in_E_B_004_02121.png
# file_name 201213_E_16_CCW_in_N_B_002_01414.png
# file_name 201213_E_18_CCW_in_N_B_001_01642.png
# file_name 201213_E_18_CCW_in_N_B_002_01000.png
# file_name 201213_E_18_CCW_in_N_B_005_00582.png
# file_name 201215_E_11_CW_in_D_B_002_00295.png
# file_name 201215_E_11_CW_in_D_B_008_00516.png
# file_name 201215_E_11_CW_in_N_B_000_00172.png
# file_name 201215_E_11_CW_in_N_B_000_00181.png
# file_name 201215_E_11_CW_in_N_B_000_00757.png
# file_name 201215_E_11_CW_in_N_B_001_00412.png
# file_name 201215_E_14_CW_in_E_B_004_00746.png
# file_name 201215_E_14_CW_in_N_B_002_00216.png
# file_name 201215_E_14_CW_in_N_B_002_00377.png
# file_name 201215_E_14_CW_in_N_B_005_00227.png
# file_name 201222_E_11_CW_in_D_C_000_01698.png
# file_name 201222_E_11_CW_in_D_C_004_01621.png
# file_name 201222_E_11_CW_in_D_C_005_00336.png
# file_name 201222_E_14_CCW_in_D_C_000_01272.png
# file_name 201222_E_14_CCW_in_D_C_001_00351.png
# file_name 201222_E_14_CCW_in_D_C_002_01370.png
# file_name 201222_E_15_CCW_in_D_C_001_00253.png
# file_name 201222_E_15_CCW_in_D_C_001_00868.png
# file_name 201222_E_15_CCW_in_D_C_001_01417.png
# file_name 201222_E_15_CCW_in_D_C_002_00965.png
# file_name 201222_E_15_CCW_in_D_C_002_01216.png
# file_name 201222_E_15_CCW_in_D_C_004_01373.png
# file_name 201222_E_15_CCW_in_D_C_005_01157.png
# file_name 201222_E_15_CCW_out_D_C_002_01764.png
# file_name 201222_E_15_CCW_out_D_C_004_00082.png
# file_name 201222_E_15_CCW_out_D_C_004_00485.png
# file_name 201222_E_15_CCW_out_D_C_006_01472.png
# file_name 201222_E_18_CCW_in_E_B_001_00666.png
# file_name 201222_E_18_CCW_in_E_B_002_00174.png
# file_name 201222_E_18_CCW_in_E_B_002_01463.png
# file_name 201222_E_18_CCW_in_E_B_003_01341.png
# file_name 201222_E_18_CCW_in_E_B_003_01549.png
# file_name 201222_E_18_CCW_in_E_B_005_01195.png
# file_name 201222_E_18_CCW_in_E_B_006_00237.png
# file_name 201222_E_18_CCW_in_E_B_007_00865.png
# file_name 201224_E_11_CCW_in_D_B_001_01313.png
# file_name 201224_E_11_CCW_in_D_B_001_01459.png
# file_name 201224_E_11_CCW_in_D_B_002_01770.png
# file_name 201224_E_11_CCW_in_D_B_003_00877.png
# file_name 201224_E_11_CCW_in_D_B_004_00078.png
# file_name 201224_E_11_CCW_in_D_B_004_01424.png
# file_name 201224_E_15_CW_in_D_B_001_00417.png
# file_name 201224_E_15_CW_in_D_B_001_00441.png
# file_name 201224_E_15_CW_in_D_B_005_00013.png
# file_name 201224_E_15_CW_in_D_B_005_00033.png
# file_name 201224_E_15_CW_in_D_B_005_00356.png
# file_name 201224_E_15_CW_in_D_B_005_01076.png
# file_name 201229_E_11_CCW_in_E_C_000_00326.png
# file_name 201229_E_11_CCW_in_E_C_001_00566.png
# file_name 201229_E_11_CCW_in_E_C_003_00039.png
# file_name 201229_E_11_CCW_in_E_C_003_00195.png
# file_name 201229_E_11_CCW_in_E_C_003_00422.png
# file_name 201229_E_11_CW_in_D_S_000_00672.png
# file_name 201229_E_11_CW_in_D_S_005_01445.png
# file_name 201229_E_14_CCW_in_E_C_000_00148.png
# file_name 201229_E_14_CCW_in_E_C_002_00772.png
# file_name 201229_E_14_CCW_in_E_C_002_01169.png
# file_name 201229_E_14_CW_in_D_S_000_00633.png
# file_name 201229_E_14_CW_in_D_S_001_00428.png
# file_name 201229_E_14_CW_in_D_S_002_00761.png
# file_name 201229_E_14_CW_in_D_S_002_01640.png
# file_name 201229_E_14_CW_in_D_S_003_00442.png
# file_name 201229_E_15_CW_in_D_S_001_01378.png
# file_name 201229_E_15_CW_in_D_S_002_00353.png
# file_name 201229_E_15_CW_in_D_S_003_01739.png
# file_name 201229_E_15_CW_in_D_S_004_00563.png
# file_name 201229_E_15_CW_in_D_S_005_00747.png
# file_name 201229_E_18_CCW_in_D_S_000_00272.png
# file_name 201229_E_18_CCW_in_D_S_000_00388.png
# file_name 201229_E_18_CCW_in_D_S_000_01373.png
# file_name 201229_E_18_CCW_in_D_S_001_01320.png
# file_name 201229_E_18_CCW_in_D_S_002_00245.png
# file_name 201229_E_18_CCW_in_D_S_002_00509.png
# file_name 201229_E_18_CCW_in_D_S_002_00990.png
# file_name 201229_E_18_CCW_in_D_S_003_01403.png
# file_name 201229_E_18_CCW_in_D_S_004_00112.png
# file_name 201229_E_18_CCW_in_D_S_005_01470.png
# file_name 201229_E_18_CCW_in_D_S_006_00392.png
# Writing Custom Labels manifest...

# %% [markdown]
# # extract box value from seg vlaue / only single json image

# %%
import json

local_path = './'
coco_json = 'road_ant_pgon_single.json'
coco_json_file = local_path + coco_json

new_json_file = 'custom_json.json'

open(local_path + new_json_file, 'w').close()

class Json_line:


    def __init__(self, img, ant, ctg):
        # Get image info. Annotations are dealt with seperately

        ############## IMAGES
        images = []
        # for img in img:
        img = img

        image = {"file_name": img["file_name"], "id": img["id"], "width": img["width"],
                     "height": img["height"]}
        images.append(image)
        print(f'file_name { img["file_name"] } ')

        ############## ANNOTATIONS
        annotations = []
        for ant_i in ant:

            for ant_i in ant:
                area = ant_i["area"]
                seg_list = ant_i["segmentation"][0]
                xcoords, ycoords = [], []
                for i in range(0, len(seg_list), 2):
                    xcoords.append(seg_list[i])
                for i in range(1, len(seg_list), 2):
                    ycoords.append(seg_list[i])
                xmax, ymin = float(max(xcoords)), float(min(ycoords))
                ymax, xmin = float(max(ycoords)), float(min(xcoords))
                # poly_bbox = [xmax, ymin, ymax, xmin]
                width, height = xmax - xmin, ymax - ymin
                bbox_values = xmin, ymin, width, height
                # print(f' bbox_values list {bbox_values}')

                annotation = {"segmentation": ant_i["segmentation"], "image_id": ant_i["image_id"],
                              # "polyline": ant["polyline"],
                              "bbox": [bbox_values], "category_id": ant_i["category_id"], "area": ant_i["area"],
                              "iscrowd": ant_i["is_crowd"], "id": ant_i["id"]}
                annotations.append(annotation)

        ############## CATEGORIES
        categories = []
        for ctg_i in ctg:
            category = {"id": ctg_i["id"], "name": ctg_i["name"],
                        # "polyline": ctg["polyline"],
                        # "id": ctg["id"]
                        # "supercategory": ctg["supercategory"], "color": ctg["color"], "metadata": ctg["metadata"],
                        # "keypoint_colors": ctg["keypoint_colors"]
                        }
            categories.append(category)

        self.__dict__['images'] = images
        self.__dict__["annotations"] = annotations
        self.__dict__["categories"] = categories    # categories


# open source json annotation file and print number of objects
with open(coco_json_file) as f:
    js = json.load(f)
    source_images = js['images']
    source_categories = js['categories']
    source_annotations = js['annotations']
    # print(source_annotations)
    # i_s = source_annotations[3]
    # i_seg = i_s['segmentation'][0]
    # print(i_seg)

    print('images: ' + str(len(source_images)))
    print('annotations: ' + str(len(source_annotations)))
    print('categories: ' + str(len(source_categories)))

# get source objects and feed them into class Json_line to process
im = Json_line(source_images, source_annotations, source_categories)

print('Writing Custom Labels manifest...')
# write new json file with new format
with open(local_path + new_json_file, 'a+') as outfile:
    # print(f' OUTFILE: ==== {outfile}')
    json.dump(im.__dict__, outfile, sort_keys=True, indent=4)
    outfile.write('\n')
    outfile.close()

print(f' Outfile: == {new_json_file} // Location: == {local_path}')
# Out:
# images: 4
# annotations: 150
# categories: 3
# file_name 201229_E_11_CCW_in_E_C_003_00039.png
# Writing Custom Labels manifest...
#  Outfile: == custom_json.json // Location: == ./

# %% [markdown]
# # rcount with spesific category id

# %% [markdown]
# # finnal code for training json coco

# %% [markdown]
# # train

# %%
import datetime
import json
import os

# data_path = './DATA/testData/'
data_path = './DATA/testData/train/'
# data_path = './DATA/testData/valid/'
# data_path = './DATA/'
#new_json_path = './out/'
new_json_path = './'
file_format = '.json'
new_json_file = 'custom_multy_coco'

class JsonAnt:
    
        # LOAD DATA
    def __init__(self):
        
        self.createDict()

    def createDict(self):
        print('Creating dict')
        jsonAnt = {"info": [        {
            "contributor": "Konkuk_university",
            "date_created": "2021/05/21",
            "description": "PGON JSON file",
            "url": "",
            "version": "1.0",
            "year": 2021
        }],
           "images": [],
           "annotations": [],
           "categories": [
#             {
#                 "id": 1,
#                 "name": "Building, Overpass, Bridge"
#             },
            {
                "id": 1,
                "name": "Road Marking, Lane Marking"
            }
#                ,
#             {
#                 "id": 3,
#                 "name": "Guard Rail, Fence, Soundproof Wall"
#             }
           ]
          }
        return jsonAnt
        

    
    def write_json(self, jsonAnt, loaded_json, num_found_files):
        
        source_infos = loaded_json['info']
        source_images = loaded_json['images']
        source_images['id'] = num_found_files 
#         print(f'source_images id : {source_images['id']}')

        source_categories = loaded_json['categories']
        source_annotations = loaded_json['annotations']
        source_annotations2 = [ ]

        for _ in source_annotations:
            if _['category_id'] == 2:
                seg_list_b = _['segmentation'][0]
    #             print(seg)
                xcoords, ycoords = [], []
                for i in range(0, len(seg_list_b), 2):
                    xcoords.append(seg_list_b[i])
                for i in range(1, len(seg_list_b), 2):
                    ycoords.append(seg_list_b[i])
                xmax, ymin = float(max(xcoords)), float(min(ycoords))
                ymax, xmin = float(max(ycoords)), float(min(xcoords))
                poly_bbox = [xmax, ymin, ymax, xmin]
                width, height = xmax - xmin, ymax - ymin
                bboxx = [xmin, ymin, width, height]
                seg_list_b = _['bbox']
    #         for _ in source_annotations:
                _['bbox'] = bboxx
                _['image_id'] = num_found_files
                _['category_id'] = 1
                source_annotations2.append(_)
                


        print('\n FILE < ' + str(num_found_files) + ' > details: ')
        source_infos_l = []
        source_infos_l.append(source_infos)
        print('info: ' + str(len(source_infos_l)))
        source_images_l = []
        source_images_l.append(source_images)
        print('images: ' + str(len(source_images_l)))
        print('annotations: ' + str(len(source_annotations2)))
        print('categories: ' + str(len(source_categories)))

        file_desc = source_infos['description']
        print(f'file type is :{file_desc[33:47]}')
        
        
        new_source_infos = jsonAnt['info']
        new_source_images = jsonAnt['images']
        new_source_categories = jsonAnt['categories']
        new_source_annotations = jsonAnt['annotations']
        
        
#         new_source_infos.append(source_infos)
#         jsonAnt['info'] = new_source_infos
        print('\n After merging the new file')
        print('new_info: ' + str(len(new_source_infos)))  

        new_source_images.append(source_images)
        jsonAnt['images'] = new_source_images
        print('new_images: ' + str(len(new_source_images)))
        tli = int(len(new_source_images))
        for ai, bi in zip(range(tli), new_source_images):
            bi['id'] = ai+1
            
#         new_source_categories.append(source_categories)
#         jsonAnt['categories'] = new_source_categories
        print('new_categories: ' + str(len(new_source_categories)))


        for i in source_annotations2:
            new_source_annotations.append(i)
        jsonAnt['annotations'] = new_source_annotations
        print('new_annotations: ' + str(len(new_source_annotations)))
        tl = int(len(new_source_annotations))
        for a, b in zip(range(tl), new_source_annotations):
            b['id'] = a
            
#         for a, b in zip(range(tl), new_source_annotations):
#             b['image_id'] = a+1
    
        return jsonAnt

        
        
        
# RUN THE PROGRAM
def main():
    
    callClass = JsonAnt()
    
    json_Ant  = callClass.createDict()

    
    
    num_found_files = 0
    print(' Loading Coco json')
    for file in os.listdir(data_path):
        
        try:
            if 'json' in file:
                num_found_files = num_found_files + 1
                json_path = os.path.join(data_path, file)
                with open(json_path) as f:
                    loaded_json = json.load(f)
#                     print(f'loaded json11 {loaded_json}')
                print('\n  Loaded!')
#                 box_v  = callClass.poly_to_bbox(loaded_json)
                callClass.write_json(json_Ant, loaded_json, num_found_files)
#                 print('\n FILE < ' + str(num_found_files) + ' > details: ')
        except:
            if 'json' not in file:
                print(' Finished, nothing to load')
                return



    

    now = datetime.datetime.now()        # creating new file name with date attached
    currentDate = "_" + str(now.day) + "_" + str(now.hour) + "_" + str(now.minute) + "_" + str(now.second)
    file_output = os.path.join(new_json_file + currentDate + file_format)
    with open(new_json_path + file_output, 'a+') as outfile:
        json.dump(json_Ant, outfile, sort_keys=True, indent=4, )  # , indent=4, im.__dict__
        outfile.write('\n')
        outfile.close()
    print(f'    Location:  {new_json_path}  \n Output file:  {file_output} \n')
    
    
if __name__ == '__main__':
    main()
# Out:
# Creating dict
# Creating dict
#  Loading Coco json
#
#   Loaded!
#
#  FILE < 1 > details:
# info: 1
# images: 1
# annotations: 19
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 1
# new_categories: 1
# new_annotations: 19
#
#   Loaded!
#
#  FILE < 2 > details:
# info: 1
# images: 1
# annotations: 91
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 2
# new_categories: 1
# new_annotations: 110
#
#   Loaded!
#
#  FILE < 3 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 3
# new_categories: 1
# new_annotations: 124
#
#   Loaded!
#
#  FILE < 4 > details:
# info: 1
# images: 1
# annotations: 42
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 4
# new_categories: 1
# new_annotations: 166
#
#   Loaded!
#
#  FILE < 5 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 5
# new_categories: 1
# new_annotations: 180
#
#   Loaded!
#
#  FILE < 6 > details:
# info: 1
# images: 1
# annotations: 51
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 6
# new_categories: 1
# new_annotations: 231
#
#   Loaded!
#
#  FILE < 7 > details:
# info: 1
# images: 1
# annotations: 41
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 7
# new_categories: 1
# new_annotations: 272
#
#   Loaded!
#
#  FILE < 8 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 8
# new_categories: 1
# new_annotations: 286
#
#   Loaded!
#
#  FILE < 9 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 9
# new_categories: 1
# new_annotations: 304
#
#   Loaded!
#
#  FILE < 10 > details:
# info: 1
# images: 1
# annotations: 123
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 10
# new_categories: 1
# new_annotations: 427
#
#   Loaded!
#
#  FILE < 11 > details:
# info: 1
# images: 1
# annotations: 4
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 11
# new_categories: 1
# new_annotations: 431
#
#   Loaded!
#
#  FILE < 12 > details:
# info: 1
# images: 1
# annotations: 28
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 12
# new_categories: 1
# new_annotations: 459
#
#   Loaded!
#
#  FILE < 13 > details:
# info: 1
# images: 1
# annotations: 15
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 13
# new_categories: 1
# new_annotations: 474
#
#   Loaded!
#
#  FILE < 14 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 14
# new_categories: 1
# new_annotations: 519
#
#   Loaded!
#
#  FILE < 15 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 15
# new_categories: 1
# new_annotations: 554
#
#   Loaded!
#
#  FILE < 16 > details:
# info: 1
# images: 1
# annotations: 55
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 16
# new_categories: 1
# new_annotations: 609
#
#   Loaded!
#
#  FILE < 17 > details:
# info: 1
# images: 1
# annotations: 25
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 17
# new_categories: 1
# new_annotations: 634
#
#   Loaded!
#
#  FILE < 18 > details:
# info: 1
# images: 1
# annotations: 89
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 18
# new_categories: 1
# new_annotations: 723
#
#   Loaded!
#
#  FILE < 19 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 19
# new_categories: 1
# new_annotations: 729
#
#   Loaded!
#
#  FILE < 20 > details:
# info: 1
# images: 1
# annotations: 10
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 20
# new_categories: 1
# new_annotations: 739
#
#   Loaded!
#
#  FILE < 21 > details:
# info: 1
# images: 1
# annotations: 61
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 21
# new_categories: 1
# new_annotations: 800
#
#   Loaded!
#
#  FILE < 22 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 22
# new_categories: 1
# new_annotations: 806
#
#   Loaded!
#
#  FILE < 23 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 23
# new_categories: 1
# new_annotations: 841
#
#   Loaded!
#
#  FILE < 24 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 24
# new_categories: 1
# new_annotations: 861
#
#   Loaded!
#
#  FILE < 25 > details:
# info: 1
# images: 1
# annotations: 11
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 25
# new_categories: 1
# new_annotations: 872
#
#   Loaded!
#
#  FILE < 26 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 26
# new_categories: 1
# new_annotations: 890
#
#   Loaded!
#
#  FILE < 27 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 27
# new_categories: 1
# new_annotations: 898
#
#   Loaded!
#
#  FILE < 28 > details:
# info: 1
# images: 1
# annotations: 15
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 28
# new_categories: 1
# new_annotations: 913
#
#   Loaded!
#
#  FILE < 29 > details:
# info: 1
# images: 1
# annotations: 17
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 29
# new_categories: 1
# new_annotations: 930
#
#   Loaded!
#
#  FILE < 30 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 30
# new_categories: 1
# new_annotations: 936
#
#   Loaded!
#
#  FILE < 31 > details:
# info: 1
# images: 1
# annotations: 30
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 31
# new_categories: 1
# new_annotations: 966
#
#   Loaded!
#
#  FILE < 32 > details:
# info: 1
# images: 1
# annotations: 28
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 32
# new_categories: 1
# new_annotations: 994
#
#   Loaded!
#
#  FILE < 33 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 33
# new_categories: 1
# new_annotations: 1010
#
#   Loaded!
#
#  FILE < 34 > details:
# info: 1
# images: 1
# annotations: 24
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 34
# new_categories: 1
# new_annotations: 1034
#
#   Loaded!
#
#  FILE < 35 > details:
# info: 1
# images: 1
# annotations: 17
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 35
# new_categories: 1
# new_annotations: 1051
#
#   Loaded!
#
#  FILE < 36 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 36
# new_categories: 1
# new_annotations: 1067
#
#   Loaded!
#
#  FILE < 37 > details:
# info: 1
# images: 1
# annotations: 19
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 37
# new_categories: 1
# new_annotations: 1086
#
#   Loaded!
#
#  FILE < 38 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 38
# new_categories: 1
# new_annotations: 1094
#
#   Loaded!
#
#  FILE < 39 > details:
# info: 1
# images: 1
# annotations: 25
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 39
# new_categories: 1
# new_annotations: 1119
#
#   Loaded!
#
#  FILE < 40 > details:
# info: 1
# images: 1
# annotations: 53
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 40
# new_categories: 1
# new_annotations: 1172
#
#   Loaded!
#
#  FILE < 41 > details:
# info: 1
# images: 1
# annotations: 5
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 41
# new_categories: 1
# new_annotations: 1177
#
#   Loaded!
#
#  FILE < 42 > details:
# info: 1
# images: 1
# annotations: 13
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 42
# new_categories: 1
# new_annotations: 1190
#
#   Loaded!
#
#  FILE < 43 > details:
# info: 1
# images: 1
# annotations: 12
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 43
# new_categories: 1
# new_annotations: 1202
#
#   Loaded!
#
#  FILE < 44 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 44
# new_categories: 1
# new_annotations: 1216
#
#   Loaded!
#
#  FILE < 45 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 45
# new_categories: 1
# new_annotations: 1276
#
#   Loaded!
#
#  FILE < 46 > details:
# info: 1
# images: 1
# annotations: 21
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 46
# new_categories: 1
# new_annotations: 1297
#
#   Loaded!
#
#  FILE < 47 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 47
# new_categories: 1
# new_annotations: 1332
#
#   Loaded!
#
#  FILE < 48 > details:
# info: 1
# images: 1
# annotations: 46
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 48
# new_categories: 1
# new_annotations: 1378
#
#   Loaded!
#
#  FILE < 49 > details:
# info: 1
# images: 1
# annotations: 55
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 49
# new_categories: 1
# new_annotations: 1433
#   Loaded!
#
#  FILE < 50 > details:
# info: 1
# images: 1
# annotations: 121
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 50
# new_categories: 1
# new_annotations: 1554
#
#   Loaded!
#
#  FILE < 51 > details:
# info: 1
# images: 1
# annotations: 26
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 51
# new_categories: 1
# new_annotations: 1580
#
#   Loaded!
#
#  FILE < 52 > details:
# info: 1
# images: 1
# annotations: 4
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 52
# new_categories: 1
# new_annotations: 1584
#
#   Loaded!
#
#  FILE < 53 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 53
# new_categories: 1
# new_annotations: 1629
#
#   Loaded!
#
#  FILE < 54 > details:
# info: 1
# images: 1
# annotations: 7
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 54
# new_categories: 1
# new_annotations: 1636
#
#   Loaded!
#
#  FILE < 55 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 55
# new_categories: 1
# new_annotations: 1696
#
#   Loaded!
#
#  FILE < 56 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 56
# new_categories: 1
# new_annotations: 1714
#
#   Loaded!
#
#  FILE < 57 > details:
# info: 1
# images: 1
# annotations: 19
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 57
# new_categories: 1
# new_annotations: 1733
#
#   Loaded!
#
#  FILE < 58 > details:
# info: 1
# images: 1
# annotations: 61
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 58
# new_categories: 1
# new_annotations: 1794
#
#   Loaded!
#
#  FILE < 59 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 59
# new_categories: 1
# new_annotations: 1800
#
#   Loaded!
#
#  FILE < 60 > details:
# info: 1
# images: 1
# annotations: 29
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 60
# new_categories: 1
# new_annotations: 1829
#
#   Loaded!
#
#  FILE < 61 > details:
# info: 1
# images: 1
# annotations: 3
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 61
# new_categories: 1
# new_annotations: 1832
#
#   Loaded!
#
#  FILE < 62 > details:
# info: 1
# images: 1
# annotations: 36
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 62
# new_categories: 1
# new_annotations: 1868
#
#   Loaded!
#
#  FILE < 63 > details:
# info: 1
# images: 1
# annotations: 55
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 63
# new_categories: 1
# new_annotations: 1923
#
#   Loaded!
#
#  FILE < 64 > details:
# info: 1
# images: 1
# annotations: 53
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 64
# new_categories: 1
# new_annotations: 1976
#
#   Loaded!
#
#  FILE < 65 > details:
# info: 1
# images: 1
# annotations: 36
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 65
# new_categories: 1
# new_annotations: 2012
#
#   Loaded!
#
#  FILE < 66 > details:
# info: 1
# images: 1
# annotations: 68
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 66
# new_categories: 1
# new_annotations: 2080
#
#   Loaded!
#
#  FILE < 67 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 67
# new_categories: 1
# new_annotations: 2088
#
#   Loaded!
#
#  FILE < 68 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 68
# new_categories: 1
# new_annotations: 2133
#
#   Loaded!
#
#  FILE < 69 > details:
# info: 1
# images: 1
# annotations: 71
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 69
# new_categories: 1
# new_annotations: 2204
#
#   Loaded!
#
#  FILE < 70 > details:
# info: 1
# images: 1
# annotations: 9
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 70
# new_categories: 1
# new_annotations: 2213
#
#   Loaded!
#
#  FILE < 71 > details:
# info: 1
# images: 1
# annotations: 22
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 71
# new_categories: 1
# new_annotations: 2235
#
#   Loaded!
#
#  FILE < 72 > details:
# info: 1
# images: 1
# annotations: 13
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 72
# new_categories: 1
# new_annotations: 2248
#
#   Loaded!
#
#  FILE < 73 > details:
# info: 1
# images: 1
# annotations: 11
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 73
# new_categories: 1
# new_annotations: 2259
#
#   Loaded!
#
#  FILE < 74 > details:
# info: 1
# images: 1
# annotations: 25
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 74
# new_categories: 1
# new_annotations: 2284
#
#   Loaded!
#
#  FILE < 75 > details:
# info: 1
# images: 1
# annotations: 11
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 75
# new_categories: 1
# new_annotations: 2295
#
#   Loaded!
#
#  FILE < 76 > details:
# info: 1
# images: 1
# annotations: 28
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 76
# new_categories: 1
# new_annotations: 2323
#
#   Loaded!
#
#  FILE < 77 > details:
# info: 1
# images: 1
# annotations: 22
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 77
# new_categories: 1
# new_annotations: 2345
#
#   Loaded!
#
#  FILE < 78 > details:
# info: 1
# images: 1
# annotations: 5
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 78
# new_categories: 1
# new_annotations: 2350
#
#   Loaded!
#
#  FILE < 79 > details:
# info: 1
# images: 1
# annotations: 44
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 79
# new_categories: 1
# new_annotations: 2394
#
#   Loaded!
#
#  FILE < 80 > details:
# info: 1
# images: 1
# annotations: 9
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 80
# new_categories: 1
# new_annotations: 2403
#
#   Loaded!
#
#  FILE < 81 > details:
# info: 1
# images: 1
# annotations: 12
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 81
# new_categories: 1
# new_annotations: 2415
#
#   Loaded!
#
#  FILE < 82 > details:
# info: 1
# images: 1
# annotations: 30
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 82
# new_categories: 1
# new_annotations: 2445
#
#   Loaded!
#
#  FILE < 83 > details:
# info: 1
# images: 1
# annotations: 13
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 83
# new_categories: 1
# new_annotations: 2458
#
#   Loaded!
#
#  FILE < 84 > details:
# info: 1
# images: 1
# annotations: 32
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 84
# new_categories: 1
# new_annotations: 2490
#
#   Loaded!
#
#  FILE < 85 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 85
# new_categories: 1
# new_annotations: 2496
#     Location:  ./
#  Output file:  custom_multy_coco_1_22_43_44.json

# %% [markdown]
# # finnal code for validatation json coco

# %% [markdown]
# # valid

# %%
import datetime
import json
import os

# data_path = './DATA/testData/'
# data_path = './DATA/testData/train/'
data_path = './DATA/testData/valid/'
# data_path = './DATA/'
#new_json_path = './out/'
new_json_path = './'
file_format = '.json'
new_json_file = 'custom_multy_coco'

class JsonAnt:
    
        # LOAD DATA
    def __init__(self):
        
        self.createDict()

    def createDict(self):
        print('Creating dict')
        jsonAnt = {"info": [        {
            "contributor": "Konkuk_university",
            "date_created": "2021/05/21",
            "description": "PGON JSON file",
            "url": "",
            "version": "1.0",
            "year": 2021
        }],
           "images": [],
           "annotations": [],
           "categories": [
#             {
#                 "id": 1,
#                 "name": "Building, Overpass, Bridge"
#             },
            {
                "id": 1,
                "name": "Road Marking, Lane Marking"
            }
#                ,
#             {
#                 "id": 3,
#                 "name": "Guard Rail, Fence, Soundproof Wall"
#             }
           ]
          }
        return jsonAnt
        

    
    def write_json(self, jsonAnt, loaded_json, num_found_files):
        
        source_infos = loaded_json['info']
        source_images = loaded_json['images']
        source_images['id'] = num_found_files 
#         print(f'source_images id : {source_images['id']}')

        source_categories = loaded_json['categories']
        source_annotations = loaded_json['annotations']
        source_annotations2 = [ ]

        for _ in source_annotations:
            if _['category_id'] == 2:
                seg_list_b = _['segmentation'][0]
    #             print(seg)
                xcoords, ycoords = [], []
                for i in range(0, len(seg_list_b), 2):
                    xcoords.append(seg_list_b[i])
                for i in range(1, len(seg_list_b), 2):
                    ycoords.append(seg_list_b[i])
                xmax, ymin = float(max(xcoords)), float(min(ycoords))
                ymax, xmin = float(max(ycoords)), float(min(xcoords))
                poly_bbox = [xmax, ymin, ymax, xmin]
                width, height = xmax - xmin, ymax - ymin
                bboxx = [xmin, ymin, width, height]
                seg_list_b = _['bbox']
    #         for _ in source_annotations:
                _['bbox'] = bboxx
                _['image_id'] = num_found_files + 86
                _['category_id'] = 1
                source_annotations2.append(_)
                


        print('\n FILE < ' + str(num_found_files) + ' > details: ')
        source_infos_l = []
        source_infos_l.append(source_infos)
        print('info: ' + str(len(source_infos_l)))
        source_images_l = []
        source_images_l.append(source_images)
        print('images: ' + str(len(source_images_l)))
        print('annotations: ' + str(len(source_annotations2)))
        print('categories: ' + str(len(source_categories)))

        file_desc = source_infos['description']
        print(f'file type is :{file_desc[33:47]}')
        
        
        new_source_infos = jsonAnt['info']
        new_source_images = jsonAnt['images']
        new_source_categories = jsonAnt['categories']
        new_source_annotations = jsonAnt['annotations']
        
        
#         new_source_infos.append(source_infos)
#         jsonAnt['info'] = new_source_infos
        print('\n After merging the new file')
        print('new_info: ' + str(len(new_source_infos)))  

        new_source_images.append(source_images)
        jsonAnt['images'] = new_source_images
        print('new_images: ' + str(len(new_source_images)))
        tli = int(len(new_source_images))
        for ai, bi in zip(range(tli), new_source_images):
            bi['id'] = ai+ 1 + 86
            
#         new_source_categories.append(source_categories)
#         jsonAnt['categories'] = new_source_categories
        print('new_categories: ' + str(len(new_source_categories)))


        for i in source_annotations2:
            new_source_annotations.append(i)
        jsonAnt['annotations'] = new_source_annotations
        print('new_annotations: ' + str(len(new_source_annotations)))
        tl = int(len(new_source_annotations))
        for a, b in zip(range(tl), new_source_annotations):
            b['id'] = a+2496
            
#         for a, b in zip(range(tl), new_source_annotations):
#             b['image_id'] = a+1
    
        return jsonAnt

        
        
        
# RUN THE PROGRAM
def main():
    
    callClass = JsonAnt()
    
    json_Ant  = callClass.createDict()

    
    
    num_found_files = 0
    print(' Loading Coco json')
    for file in os.listdir(data_path):
        
        try:
            if 'json' in file:
                num_found_files = num_found_files + 1
                json_path = os.path.join(data_path, file)
                with open(json_path) as f:
                    loaded_json = json.load(f)
#                     print(f'loaded json11 {loaded_json}')
                print('\n  Loaded!')
#                 box_v  = callClass.poly_to_bbox(loaded_json)
                callClass.write_json(json_Ant, loaded_json, num_found_files)
#                 print('\n FILE < ' + str(num_found_files) + ' > details: ')
        except:
            if 'json' not in file:
                print(' Finished, nothing to load')
                return



    

    now = datetime.datetime.now()        # creating new file name with date attached
    currentDate = "_" + str(now.day) + "_" + str(now.hour) + "_" + str(now.minute) + "_" + str(now.second)
    file_output = os.path.join(new_json_file + currentDate + file_format)
    with open(new_json_path + file_output, 'a+') as outfile:
        json.dump(json_Ant, outfile, sort_keys=True, indent=4, )  # , indent=4, im.__dict__
        outfile.write('\n')
        outfile.close()
    print(f'    Location:  {new_json_path}  \n Output file:  {file_output} \n')
    
    
if __name__ == '__main__':
    main()
# Out:
# Creating dict
# Creating dict
#  Loading Coco json
#
#   Loaded!
#
#  FILE < 1 > details:
# info: 1
# images: 1
# annotations: 51
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 1
# new_categories: 1
# new_annotations: 51
#
#   Loaded!
#
#  FILE < 2 > details:
# info: 1
# images: 1
# annotations: 3
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 2
# new_categories: 1
# new_annotations: 54
#
#   Loaded!
#
#  FILE < 3 > details:
# info: 1
# images: 1
# annotations: 41
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 3
# new_categories: 1
# new_annotations: 95
#
#   Loaded!
#
#  FILE < 4 > details:
# info: 1
# images: 1
# annotations: 21
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 4
# new_categories: 1
# new_annotations: 116
#
#   Loaded!
#
#  FILE < 5 > details:
# info: 1
# images: 1
# annotations: 11
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 5
# new_categories: 1
# new_annotations: 127
#
#   Loaded!
#
#  FILE < 6 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 6
# new_categories: 1
# new_annotations: 133
#
#   Loaded!
#
#  FILE < 7 > details:
# info: 1
# images: 1
# annotations: 3
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 7
# new_categories: 1
# new_annotations: 136
#
#   Loaded!
#
#  FILE < 8 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 8
# new_categories: 1
# new_annotations: 154
#
#   Loaded!
#
#  FILE < 9 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 9
# new_categories: 1
# new_annotations: 174
#
#   Loaded!
#
#  FILE < 10 > details:
# info: 1
# images: 1
# annotations: 13
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 10
# new_categories: 1
# new_annotations: 187
#
#   Loaded!
#
#  FILE < 11 > details:
# info: 1
# images: 1
# annotations: 22
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 11
# new_categories: 1
# new_annotations: 209
#
#   Loaded!
#
#  FILE < 12 > details:
# info: 1
# images: 1
# annotations: 58
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 12
# new_categories: 1
# new_annotations: 267
#
#   Loaded!
#
#  FILE < 13 > details:
# info: 1
# images: 1
# annotations: 19
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 13
# new_categories: 1
# new_annotations: 286
#
#   Loaded!
#
#  FILE < 14 > details:
# info: 1
# images: 1
# annotations: 4
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 14
# new_categories: 1
# new_annotations: 290
#
#   Loaded!
#
#  FILE < 15 > details:
# info: 1
# images: 1
# annotations: 30
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 15
# new_categories: 1
# new_annotations: 320
#     Location:  ./
#  Output file:  custom_multy_coco_1_22_46_8.json

# %% [markdown]
# # recount id

# %% [markdown]
# ### Train only

# %%
import datetime
import json
import os

data_path = './DATA/testData/train/'
# data_path = './DATA/testData/valid/'
# data_path = './DATA/testData/'
# data_path = './DATA/'
#new_json_path = './out/'
new_json_path = './'
file_format = '.json'
new_json_file = 'custom_multy_coco'

class JsonAnt:
    
        # LOAD DATA
    def __init__(self):
        
        self.createDict()

    def createDict(self):
        print('Creating dict')
        jsonAnt = {"info": [        {
            "contributor": "Konkuk_university",
            "date_created": "2021/05/21",
            "description": "PGON JSON file",
            "url": "",
            "version": "1.0",
            "year": 2021
        }],
           "images": [],
           "annotations": [],
           "categories": [
            {
                "id": 1,
                "name": "Building, Overpass, Bridge"
            },
            {
                "id": 2,
                "name": "Road Marking, Lane Marking"
            },
            {
                "id": 3,
                "name": "Guard Rail, Fence, Soundproof Wall"
            }]
          }
        return jsonAnt
        

    
    def write_json(self, jsonAnt, loaded_json, num_found_files):
        
        source_infos = loaded_json['info']
        source_images = loaded_json['images']
        source_images['id'] = num_found_files
#         print(f'source_images id : {source_images['id']}')

        source_categories = loaded_json['categories']
        source_annotations = loaded_json['annotations']
        for _ in source_annotations:
            seg_list_b = _['segmentation'][0]
#             print(seg)
            xcoords, ycoords = [], []
            for i in range(0, len(seg_list_b), 2):
                xcoords.append(seg_list_b[i])
            for i in range(1, len(seg_list_b), 2):
                ycoords.append(seg_list_b[i])
            xmax, ymin = float(max(xcoords)), float(min(ycoords))
            ymax, xmin = float(max(ycoords)), float(min(xcoords))
            poly_bbox = [xmax, ymin, ymax, xmin]
            width, height = xmax - xmin, ymax - ymin
            bboxx = [xmin, ymin, width, height]
            seg_list_b = _['bbox']
#         for _ in source_annotations:
            _['bbox'] = bboxx
            _['image_id'] = num_found_files


        print('\n FILE < ' + str(num_found_files) + ' > details: ')
        source_infos_l = []
        source_infos_l.append(source_infos)
        print('info: ' + str(len(source_infos_l)))
        source_images_l = []
        source_images_l.append(source_images)
        print('images: ' + str(len(source_images_l)))
        print('annotations: ' + str(len(source_annotations)))
        print('categories: ' + str(len(source_categories)))

        file_desc = source_infos['description']
        print(f'file type is :{file_desc[33:47]}')
        
        
        new_source_infos = jsonAnt['info']
        new_source_images = jsonAnt['images']
        new_source_categories = jsonAnt['categories']
        new_source_annotations = jsonAnt['annotations']
        
        
#         new_source_infos.append(source_infos)
#         jsonAnt['info'] = new_source_infos
        print('\n After merging the new file')
        print('new_info: ' + str(len(new_source_infos)))  

        new_source_images.append(source_images)
        jsonAnt['images'] = new_source_images
        print('new_images: ' + str(len(new_source_images)))
        tli = int(len(new_source_images))
        for ai, bi in zip(range(tli), new_source_images):
            bi['id'] = ai+1
            
#         new_source_categories.append(source_categories)
#         jsonAnt['categories'] = new_source_categories
        print('new_categories: ' + str(len(new_source_categories)))


        for i in source_annotations:
            new_source_annotations.append(i)
        jsonAnt['annotations'] = new_source_annotations
        print('new_annotations: ' + str(len(new_source_annotations)))
        tl = int(len(new_source_annotations))
        for a, b in zip(range(tl), new_source_annotations):
            b['id'] = a+1
            
#         for a, b in zip(range(tl), new_source_annotations):
#             b['image_id'] = a+1
    
        return jsonAnt

        
        
        
# RUN THE PROGRAM
def main():
    
    callClass = JsonAnt()
    
    json_Ant  = callClass.createDict()

    
    
    num_found_files = 0
    print(' Loading Coco json')
    for file in os.listdir(data_path):
        
        try:
            if 'json' in file:
                num_found_files = num_found_files + 1
                json_path = os.path.join(data_path, file)
                with open(json_path) as f:
                    loaded_json = json.load(f)
#                     print(f'loaded json11 {loaded_json}')
                print('\n  Loaded!')
#                 box_v  = callClass.poly_to_bbox(loaded_json)
                callClass.write_json(json_Ant, loaded_json, num_found_files)
#                 print('\n FILE < ' + str(num_found_files) + ' > details: ')
        except:
            if 'json' not in file:
                print(' Finished, nothing to load')
                return



    

    now = datetime.datetime.now()        # creating new file name with date attached
    currentDate = "_" + str(now.day) + "_" + str(now.hour) + "_" + str(now.minute) + "_" + str(now.second)
    file_output = os.path.join(new_json_file + currentDate + file_format)
    with open(new_json_path + file_output, 'a+') as outfile:
        json.dump(json_Ant, outfile, sort_keys=True, indent=4, )  # , indent=4, im.__dict__
        outfile.write('\n')
        outfile.close()
    print(f'    Location:  {new_json_path}  \n Output file:  {file_output} \n')
    
    
if __name__ == '__main__':
    main()
# Out:
# Creating dict
# Creating dict
#  Loading Coco json
#
#   Loaded!
#
#  FILE < 1 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 1
# new_categories: 3
# new_annotations: 45
#
#   Loaded!
#
#  FILE < 2 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 2
# new_categories: 3
# new_annotations: 105
#
#   Loaded!
#
#  FILE < 3 > details:
# info: 1
# images: 1
# annotations: 47
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 3
# new_categories: 3
# new_annotations: 152
#
#   Loaded!
#
#  FILE < 4 > details:
# info: 1
# images: 1
# annotations: 31
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 4
# new_categories: 3
# new_annotations: 183
#
#   Loaded!
#
#  FILE < 5 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 5
# new_categories: 3
# new_annotations: 199
#
#   Loaded!
#
#  FILE < 6 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 6
# new_categories: 3
# new_annotations: 213
#
#   Loaded!
#
#  FILE < 7 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 7
# new_categories: 3
# new_annotations: 231
#
#   Loaded!
#
#  FILE < 8 > details:
# info: 1
# images: 1
# annotations: 96
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 8
# new_categories: 3
# new_annotations: 327
#
#   Loaded!
#
#  FILE < 9 > details:
# info: 1
# images: 1
# annotations: 82
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 9
# new_categories: 3
# new_annotations: 409
#
#   Loaded!
#
#  FILE < 10 > details:
# info: 1
# images: 1
# annotations: 52
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 10
# new_categories: 3
# new_annotations: 461
#
#   Loaded!
#
#  FILE < 11 > details:
# info: 1
# images: 1
# annotations: 71
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 11
# new_categories: 3
# new_annotations: 532
#
#   Loaded!
#
#  FILE < 12 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 12
# new_categories: 3
# new_annotations: 577
#
#   Loaded!
#
#  FILE < 13 > details:
# info: 1
# images: 1
# annotations: 54
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 13
# new_categories: 3
# new_annotations: 631
#
#   Loaded!
#
#  FILE < 14 > details:
# info: 1
# images: 1
# annotations: 56
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 14
# new_categories: 3
# new_annotations: 687
#
#   Loaded!
#
#  FILE < 15 > details:
# info: 1
# images: 1
# annotations: 39
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 15
# new_categories: 3
# new_annotations: 726
#
#   Loaded!
#
#  FILE < 16 > details:
# info: 1
# images: 1
# annotations: 32
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 16
# new_categories: 3
# new_annotations: 758
#
#   Loaded!
#
#  FILE < 17 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 17
# new_categories: 3
# new_annotations: 778
#
#   Loaded!
#
#  FILE < 18 > details:
# info: 1
# images: 1
# annotations: 46
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 18
# new_categories: 3
# new_annotations: 824
#
#   Loaded!
#
#  FILE < 19 > details:
# info: 1
# images: 1
# annotations: 34
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 19
# new_categories: 3
# new_annotations: 858
#
#   Loaded!
#
#  FILE < 20 > details:
# info: 1
# images: 1
# annotations: 55
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 20
# new_categories: 3
# new_annotations: 913
#
#   Loaded!
#
#  FILE < 21 > details:
# info: 1
# images: 1
# annotations: 41
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 21
# new_categories: 3
# new_annotations: 954
#
#   Loaded!
#
#  FILE < 22 > details:
# info: 1
# images: 1
# annotations: 31
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 22
# new_categories: 3
# new_annotations: 985
#
#   Loaded!
#
#  FILE < 23 > details:
# info: 1
# images: 1
# annotations: 21
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 23
# new_categories: 3
# new_annotations: 1006
#
#   Loaded!
#
#  FILE < 24 > details:
# info: 1
# images: 1
# annotations: 26
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 24
# new_categories: 3
# new_annotations: 1032
#
#   Loaded!
#
#  FILE < 25 > details:
# info: 1
# images: 1
# annotations: 17
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 25
# new_categories: 3
# new_annotations: 1049
#
#   Loaded!
#
#  FILE < 26 > details:
# info: 1
# images: 1
# annotations: 29
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 26
# new_categories: 3
# new_annotations: 1078
#
#   Loaded!
#
#  FILE < 27 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 27
# new_categories: 3
# new_annotations: 1084
#
#   Loaded!
#
#  FILE < 28 > details:
# info: 1
# images: 1
# annotations: 13
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 28
# new_categories: 3
# new_annotations: 1097
#
#   Loaded!
#
#  FILE < 29 > details:
# info: 1
# images: 1
# annotations: 22
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 29
# new_categories: 3
# new_annotations: 1119
#
#   Loaded!
#
#  FILE < 30 > details:
# info: 1
# images: 1
# annotations: 92
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 30
# new_categories: 3
# new_annotations: 1211
#
#   Loaded!
#
#  FILE < 31 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 31
# new_categories: 3
# new_annotations: 1231
#
#   Loaded!
#
#  FILE < 32 > details:
# info: 1
# images: 1
# annotations: 77
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 32
# new_categories: 3
# new_annotations: 1308
#
#   Loaded!
#
#  FILE < 33 > details:
# info: 1
# images: 1
# annotations: 39
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 33
# new_categories: 3
# new_annotations: 1347
#
#   Loaded!
#
#  FILE < 34 > details:
# info: 1
# images: 1
# annotations: 41
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 34
# new_categories: 3
# new_annotations: 1388
#
#   Loaded!
#
#  FILE < 35 > details:
# info: 1
# images: 1
# annotations: 48
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 35
# new_categories: 3
# new_annotations: 1436
#
#   Loaded!
#
#  FILE < 36 > details:
# info: 1
# images: 1
# annotations: 7
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 36
# new_categories: 3
# new_annotations: 1443
#
#   Loaded!
#
#  FILE < 37 > details:
# info: 1
# images: 1
# annotations: 24
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 37
# new_categories: 3
# new_annotations: 1467
#
#   Loaded!
#
#  FILE < 38 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 38
# new_categories: 3
# new_annotations: 1475
#
#   Loaded!
#
#  FILE < 39 > details:
# info: 1
# images: 1
# annotations: 19
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 39
# new_categories: 3
# new_annotations: 1494
#
#   Loaded!
#
#  FILE < 40 > details:
# info: 1
# images: 1
# annotations: 36
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 40
# new_categories: 3
# new_annotations: 1530
#
#   Loaded!
#
#  FILE < 41 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 41
# new_categories: 3
# new_annotations: 1550
#
#   Loaded!
#
#  FILE < 42 > details:
# info: 1
# images: 1
# annotations: 17
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 42
# new_categories: 3
# new_annotations: 1567
#
#   Loaded!
#
#  FILE < 43 > details:
# info: 1
# images: 1
# annotations: 31
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 43
# new_categories: 3
# new_annotations: 1598
#
#   Loaded!
#
#  FILE < 44 > details:
# info: 1
# images: 1
# annotations: 37
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 44
# new_categories: 3
# new_annotations: 1635
#
#   Loaded!
#
#  FILE < 45 > details:
# info: 1
# images: 1
# annotations: 66
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 45
# new_categories: 3
# new_annotations: 1701
#
#   Loaded!
#
#  FILE < 46 > details:
# info: 1
# images: 1
# annotations: 26
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 46
# new_categories: 3
# new_annotations: 1727
#
#   Loaded!
#
#  FILE < 47 > details:
# info: 1
# images: 1
# annotations: 48
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 47
# new_categories: 3
# new_annotations: 1775
#
#   Loaded!
#
#  FILE < 48 > details:
# info: 1
# images: 1
# annotations: 57
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 48
# new_categories: 3
# new_annotations: 1832
#
#   Loaded!
#
#  FILE < 49 > details:
# info: 1
# images: 1
# annotations: 83
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 49
# new_categories: 3
# new_annotations: 1915
#
#   Loaded!
#
#  FILE < 50 > details:
# info: 1
# images: 1
# annotations: 38
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 50
# new_categories: 3
# new_annotations: 1953
#
#   Loaded!
#
#  FILE < 51 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 51
# new_categories: 3
# new_annotations: 1969
#
#   Loaded!
#
#  FILE < 52 > details:
# info: 1
# images: 1
# annotations: 23
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 52
# new_categories: 3
# new_annotations: 1992
#
#   Loaded!
#
#  FILE < 53 > details:
# info: 1
# images: 1
# annotations: 28
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 53
# new_categories: 3
# new_annotations: 2020
#
#   Loaded!
#
#  FILE < 54 > details:
# info: 1
# images: 1
# annotations: 27
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 54
# new_categories: 3
# new_annotations: 2047
#
#   Loaded!
#
#  FILE < 55 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 55
# new_categories: 3
# new_annotations: 2107
#
#   Loaded!
#
#  FILE < 56 > details:
# info: 1
# images: 1
# annotations: 38
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 56
# new_categories: 3
# new_annotations: 2145
#
#   Loaded!
#
#  FILE < 57 > details:
# info: 1
# images: 1
# annotations: 150
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 57
# new_categories: 3
# new_annotations: 2295
#
#   Loaded!
#
#  FILE < 58 > details:
# info: 1
# images: 1
# annotations: 149
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 58
# new_categories: 3
# new_annotations: 2444
#
#   Loaded!
#
#  FILE < 59 > details:
# info: 1
# images: 1
# annotations: 50
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 59
# new_categories: 3
# new_annotations: 2494
#
#   Loaded!
#
#  FILE < 60 > details:
# info: 1
# images: 1
# annotations: 64
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 60
# new_categories: 3
# new_annotations: 2558
#
#   Loaded!
#
#  FILE < 61 > details:
# info: 1
# images: 1
# annotations: 24
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 61
# new_categories: 3
# new_annotations: 2582
#
#   Loaded!
#
#  FILE < 62 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 62
# new_categories: 3
# new_annotations: 2617
#
#   Loaded!
#
#  FILE < 63 > details:
# info: 1
# images: 1
# annotations: 65
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 63
# new_categories: 3
# new_annotations: 2682
#
#   Loaded!
#
#  FILE < 64 > details:
# info: 1
# images: 1
# annotations: 26
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 64
# new_categories: 3
# new_annotations: 2708
#
#   Loaded!
#
#  FILE < 65 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 65
# new_categories: 3
# new_annotations: 2726
#
#   Loaded!
#
#  FILE < 66 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 66
# new_categories: 3
# new_annotations: 2786
#
#   Loaded!
#
#  FILE < 67 > details:
# info: 1
# images: 1
# annotations: 70
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 67
# new_categories: 3
# new_annotations: 2856
#
#   Loaded!
#
#  FILE < 68 > details:
# info: 1
# images: 1
# annotations: 69
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 68
# new_categories: 3
# new_annotations: 2925
#
#   Loaded!
#
#  FILE < 69 > details:
# info: 1
# images: 1
# annotations: 49
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 69
# new_categories: 3
# new_annotations: 2974
#
#   Loaded!
#
#  FILE < 70 > details:
# info: 1
# images: 1
# annotations: 15
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 70
# new_categories: 3
# new_annotations: 2989
#
#   Loaded!
#
#  FILE < 71 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 71
# new_categories: 3
# new_annotations: 3024
#
#   Loaded!
#
#  FILE < 72 > details:
# info: 1
# images: 1
# annotations: 15
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 72
# new_categories: 3
# new_annotations: 3039
#
#   Loaded!
#
#  FILE < 73 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 73
# new_categories: 3
# new_annotations: 3059
#
#   Loaded!
#
#  FILE < 74 > details:
# info: 1
# images: 1
# annotations: 33
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 74
# new_categories: 3
# new_annotations: 3092
#
#   Loaded!
#
#  FILE < 75 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 75
# new_categories: 3
# new_annotations: 3112
#
#   Loaded!
#
#  FILE < 76 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 76
# new_categories: 3
# new_annotations: 3147
#
#   Loaded!
#
#  FILE < 77 > details:
# info: 1
# images: 1
# annotations: 9
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 77
# new_categories: 3
# new_annotations: 3156
#
#   Loaded!
#
#  FILE < 78 > details:
# info: 1
# images: 1
# annotations: 7
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 78
# new_categories: 3
# new_annotations: 3163
#
#   Loaded!
#
#  FILE < 79 > details:
# info: 1
# images: 1
# annotations: 21
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 79
# new_categories: 3
# new_annotations: 3184
#
#   Loaded!
#
#  FILE < 80 > details:
# info: 1
# images: 1
# annotations: 44
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 80
# new_categories: 3
# new_annotations: 3228
#
#   Loaded!
#
#  FILE < 81 > details:
# info: 1
# images: 1
# annotations: 12
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 81
# new_categories: 3
# new_annotations: 3240
#
#   Loaded!
#
#  FILE < 82 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 82
# new_categories: 3
# new_annotations: 3256
#
#   Loaded!
#
#  FILE < 83 > details:
# info: 1
# images: 1
# annotations: 10
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 83
# new_categories: 3
# new_annotations: 3266
#
#   Loaded!
#
#  FILE < 84 > details:
# info: 1
# images: 1
# annotations: 5
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 84
# new_categories: 3
# new_annotations: 3271
#
#   Loaded!
#
#  FILE < 85 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 85
# new_categories: 3
# new_annotations: 3279
#     Location:  ./
#  Output file:  custom_multy_coco_28_13_34_51.json

# %% [markdown]
# ### validate only

# %%
import datetime
import json
import os

# data_path = './DATA/testData/train/'
data_path = './DATA/testData/valid/'
# data_path = './DATA/testData/'
# data_path = './DATA/'
#new_json_path = './out/'
new_json_path = './'
file_format = '.json'
new_json_file = 'custom_multy_coco'

class JsonAnt:
    
        # LOAD DATA
    def __init__(self):
        
        self.createDict()

    def createDict(self):
        print('Creating dict')
        jsonAnt = {"info": [        {
            "contributor": "Konkuk_university",
            "date_created": "2021/05/21",
            "description": "PGON JSON file",
            "url": "",
            "version": "1.0",
            "year": 2021
        }],
           "images": [],
           "annotations": [],
           "categories": [
            {
                "id": 1,
                "name": "Building, Overpass, Bridge"
            },
            {
                "id": 2,
                "name": "Road Marking, Lane Marking"
            },
            {
                "id": 3,
                "name": "Guard Rail, Fence, Soundproof Wall"
            }]
          }
        return jsonAnt
        

    
    def write_json(self, jsonAnt, loaded_json, num_found_files):
        
        source_infos = loaded_json['info']
        source_images = loaded_json['images']
        source_images['id'] = num_found_files
#         print(f'source_images id : {source_images['id']}')

        source_categories = loaded_json['categories']
        source_annotations = loaded_json['annotations']
        for _ in source_annotations:
            seg_list_b = _['segmentation'][0]
#             print(seg)
            xcoords, ycoords = [], []
            for i in range(0, len(seg_list_b), 2):
                xcoords.append(seg_list_b[i])
            for i in range(1, len(seg_list_b), 2):
                ycoords.append(seg_list_b[i])
            xmax, ymin = float(max(xcoords)), float(min(ycoords))
            ymax, xmin = float(max(ycoords)), float(min(xcoords))
            poly_bbox = [xmax, ymin, ymax, xmin]
            width, height = xmax - xmin, ymax - ymin
            bboxx = [xmin, ymin, width, height]
            seg_list_b = _['bbox']
#         for _ in source_annotations:
            _['bbox'] = bboxx
            _['image_id'] = num_found_files + 86
            


        print('\n FILE < ' + str(num_found_files) + ' > details: ')
        source_infos_l = []
        source_infos_l.append(source_infos)
        print('info: ' + str(len(source_infos_l)))
        source_images_l = []
        source_images_l.append(source_images)
        print('images: ' + str(len(source_images_l)))
        print('annotations: ' + str(len(source_annotations)))
        print('categories: ' + str(len(source_categories)))

        file_desc = source_infos['description']
        print(f'file type is :{file_desc[33:47]}')
        
        
        new_source_infos = jsonAnt['info']
        new_source_images = jsonAnt['images']
        new_source_categories = jsonAnt['categories']
        new_source_annotations = jsonAnt['annotations']
        
        
#         new_source_infos.append(source_infos)
#         jsonAnt['info'] = new_source_infos
        print('\n After merging the new file')
        print('new_info: ' + str(len(new_source_infos)))  

        new_source_images.append(source_images)
        jsonAnt['images'] = new_source_images
        print('new_images: ' + str(len(new_source_images)))
        tli = int(len(new_source_images))
        for ai, bi in zip(range(tli), new_source_images):
            bi['id'] = ai+86
            
#         new_source_categories.append(source_categories)
#         jsonAnt['categories'] = new_source_categories
        print('new_categories: ' + str(len(new_source_categories)))


        for i in source_annotations:
            new_source_annotations.append(i)
        jsonAnt['annotations'] = new_source_annotations
        print('new_annotations: ' + str(len(new_source_annotations)))
        tl = int(len(new_source_annotations))
        for a, b in zip(range(tl), new_source_annotations):
            b['id'] = a+ 3280
            
#         for a, b in zip(range(tl), new_source_annotations):
#             b['image_id'] = a+1
    
        return jsonAnt

        
        
        
# RUN THE PROGRAM
def main():
    
    callClass = JsonAnt()
    
    json_Ant  = callClass.createDict()

    
    
    num_found_files = 0
    print(' Loading Coco json')
    for file in os.listdir(data_path):
        
        try:
            if 'json' in file:
                num_found_files = num_found_files + 1
                json_path = os.path.join(data_path, file)
                with open(json_path) as f:
                    loaded_json = json.load(f)
#                     print(f'loaded json11 {loaded_json}')
                print('\n  Loaded!')
#                 box_v  = callClass.poly_to_bbox(loaded_json)
                callClass.write_json(json_Ant, loaded_json, num_found_files)
#                 print('\n FILE < ' + str(num_found_files) + ' > details: ')
        except:
            if 'json' not in file:
                print(' Finished, nothing to load')
                return



    

    now = datetime.datetime.now()        # creating new file name with date attached
    currentDate = "_" + str(now.day) + "_" + str(now.hour) + "_" + str(now.minute) + "_" + str(now.second)
    file_output = os.path.join(new_json_file + currentDate + file_format)
    with open(new_json_path + file_output, 'a+') as outfile:
        json.dump(json_Ant, outfile, sort_keys=True, indent=4, )  # , indent=4, im.__dict__
        outfile.write('\n')
        outfile.close()
    print(f'    Location:  {new_json_path}  \n Output file:  {file_output} \n')
    
    
if __name__ == '__main__':
    main()
# Out:
# Creating dict
# Creating dict
#  Loading Coco json
#
#   Loaded!
#
#  FILE < 1 > details:
# info: 1
# images: 1
# annotations: 39
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 1
# new_categories: 3
# new_annotations: 39
#
#   Loaded!
#
#  FILE < 2 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 2
# new_categories: 3
# new_annotations: 84
#
#   Loaded!
#
#  FILE < 3 > details:
# info: 1
# images: 1
# annotations: 71
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 3
# new_categories: 3
# new_annotations: 155
#
#   Loaded!
#
#  FILE < 4 > details:
# info: 1
# images: 1
# annotations: 30
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 4
# new_categories: 3
# new_annotations: 185
#
#   Loaded!
#
#  FILE < 5 > details:
# info: 1
# images: 1
# annotations: 70
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 5
# new_categories: 3
# new_annotations: 255
#
#   Loaded!
#
#  FILE < 6 > details:
# info: 1
# images: 1
# annotations: 27
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 6
# new_categories: 3
# new_annotations: 282
#
#   Loaded!
#
#  FILE < 7 > details:
# info: 1
# images: 1
# annotations: 4
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 7
# new_categories: 3
# new_annotations: 286
#
#   Loaded!
#
#  FILE < 8 > details:
# info: 1
# images: 1
# annotations: 17
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 8
# new_categories: 3
# new_annotations: 303
#
#   Loaded!
#
#  FILE < 9 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 9
# new_categories: 3
# new_annotations: 348
#
#   Loaded!
#
#  FILE < 10 > details:
# info: 1
# images: 1
# annotations: 25
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 10
# new_categories: 3
# new_annotations: 373
#
#   Loaded!
#
#  FILE < 11 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 11
# new_categories: 3
# new_annotations: 393
#
#   Loaded!
#
#  FILE < 12 > details:
# info: 1
# images: 1
# annotations: 5
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 12
# new_categories: 3
# new_annotations: 398
#
#   Loaded!
#
#  FILE < 13 > details:
# info: 1
# images: 1
# annotations: 5
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 13
# new_categories: 3
# new_annotations: 403
#
#   Loaded!
#
#  FILE < 14 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 14
# new_categories: 3
# new_annotations: 409
#
#   Loaded!
#
#  FILE < 15 > details:
# info: 1
# images: 1
# annotations: 29
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 15
# new_categories: 3
# new_annotations: 438
#     Location:  ./
#  Output file:  custom_multy_coco_28_13_33_33.json

# %% [markdown]
# # extract spesific categories only
# # COUNT FILES AND UPDATE IDs
# # EXTRACT BBOX VALUES FROM POLY VALUES
# # MERGE MULTY JSON FILES INTO ONE

# %%
import datetime
import json
import os

# data_path = './DATA/testData/'
data_path = './DATA/testData/train/'
# data_path = './DATA/testData/valid/'
# data_path = './DATA/'
#new_json_path = './out/'
new_json_path = './'
file_format = '.json'
new_json_file = 'custom_multy_coco'

class JsonAnt:
    
        # LOAD DATA
    def __init__(self):
        
        self.createDict()

    def createDict(self):
        print('Creating dict')
        jsonAnt = {"info": [        {
            "contributor": "Konkuk_university",
            "date_created": "2021/05/21",
            "description": "PGON JSON file",
            "url": "",
            "version": "1.0",
            "year": 2021
        }],
           "images": [],
           "annotations": [],
           "categories": [
            {
                "id": 1,
                "name": "Building, Overpass, Bridge"
            },
            {
                "id": 2,
                "name": "Road Marking, Lane Marking"
            },
            {
                "id": 3,
                "name": "Guard Rail, Fence, Soundproof Wall"
            }]
          }
        return jsonAnt
        

    
    def write_json(self, jsonAnt, loaded_json, num_found_files):
        
        source_infos = loaded_json['info']
        source_images = loaded_json['images']
        source_images['id'] = num_found_files
#         print(f'source_images id : {source_images['id']}')

        source_categories = loaded_json['categories']
        source_annotations = loaded_json['annotations']
        source_annotations2 = [ ]
        for _ in source_annotations:
            seg_list_b = _['segmentation'][0]
#             print(seg)
            xcoords, ycoords = [], []
            for i in range(0, len(seg_list_b), 2):
                xcoords.append(seg_list_b[i])
            for i in range(1, len(seg_list_b), 2):
                ycoords.append(seg_list_b[i])
            xmax, ymin = float(max(xcoords)), float(min(ycoords))
            ymax, xmin = float(max(ycoords)), float(min(xcoords))
            poly_bbox = [xmax, ymin, ymax, xmin]
            width, height = xmax - xmin, ymax - ymin
            bboxx = [xmin, ymin, width, height]
            seg_list_b = _['bbox']
#         for _ in source_annotations:
            _['bbox'] = bboxx
            _['image_id'] = num_found_files
            if _['category_id'] == 2:
                source_annotations2.append(_)
                


        print('\n FILE < ' + str(num_found_files) + ' > details: ')
        source_infos_l = []
        source_infos_l.append(source_infos)
        print('info: ' + str(len(source_infos_l)))
        source_images_l = []
        source_images_l.append(source_images)
        print('images: ' + str(len(source_images_l)))
        print('annotations: ' + str(len(source_annotations2)))
        print('categories: ' + str(len(source_categories)))

        file_desc = source_infos['description']
        print(f'file type is :{file_desc[33:47]}')
        
        
        new_source_infos = jsonAnt['info']
        new_source_images = jsonAnt['images']
        new_source_categories = jsonAnt['categories']
        new_source_annotations = jsonAnt['annotations']
        
        
#         new_source_infos.append(source_infos)
#         jsonAnt['info'] = new_source_infos
        print('\n After merging the new file')
        print('new_info: ' + str(len(new_source_infos)))  

        new_source_images.append(source_images)
        jsonAnt['images'] = new_source_images
        print('new_images: ' + str(len(new_source_images)))
        tli = int(len(new_source_images))
        for ai, bi in zip(range(tli), new_source_images):
            bi['id'] = ai+1
            
#         new_source_categories.append(source_categories)
#         jsonAnt['categories'] = new_source_categories
        print('new_categories: ' + str(len(new_source_categories)))


        for i in source_annotations2:
            new_source_annotations.append(i)
        jsonAnt['annotations'] = new_source_annotations
        print('new_annotations: ' + str(len(new_source_annotations)))
        tl = int(len(new_source_annotations))
        for a, b in zip(range(tl), new_source_annotations):
            b['id'] = a+1
            
#         for a, b in zip(range(tl), new_source_annotations):
#             b['image_id'] = a+1
    
        return jsonAnt

        
        
        
# RUN THE PROGRAM
def main():
    
    callClass = JsonAnt()
    
    json_Ant  = callClass.createDict()

    
    
    num_found_files = 0
    print(' Loading Coco json')
    for file in os.listdir(data_path):
        
        try:
            if 'json' in file:
                num_found_files = num_found_files + 1
                json_path = os.path.join(data_path, file)
                with open(json_path) as f:
                    loaded_json = json.load(f)
#                     print(f'loaded json11 {loaded_json}')
                print('\n  Loaded!')
#                 box_v  = callClass.poly_to_bbox(loaded_json)
                callClass.write_json(json_Ant, loaded_json, num_found_files)
#                 print('\n FILE < ' + str(num_found_files) + ' > details: ')
        except:
            if 'json' not in file:
                print(' Finished, nothing to load')
                return



    

    now = datetime.datetime.now()        # creating new file name with date attached
    currentDate = "_" + str(now.day) + "_" + str(now.hour) + "_" + str(now.minute) + "_" + str(now.second)
    file_output = os.path.join(new_json_file + currentDate + file_format)
    with open(new_json_path + file_output, 'a+') as outfile:
        json.dump(json_Ant, outfile, sort_keys=True, indent=4, )  # , indent=4, im.__dict__
        outfile.write('\n')
        outfile.close()
    print(f'    Location:  {new_json_path}  \n Output file:  {file_output} \n')
    
    
if __name__ == '__main__':
    main()
# Out:
# Creating dict
# Creating dict
#  Loading Coco json
#
#   Loaded!
#
#  FILE < 1 > details:
# info: 1
# images: 1
# annotations: 32
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 1
# new_categories: 3
# new_annotations: 32
#
#   Loaded!
#
#  FILE < 2 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 2
# new_categories: 3
# new_annotations: 50
#
#   Loaded!
#
#  FILE < 3 > details:
# info: 1
# images: 1
# annotations: 44
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 3
# new_categories: 3
# new_annotations: 94
#
#   Loaded!
#
#  FILE < 4 > details:
# info: 1
# images: 1
# annotations: 22
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 4
# new_categories: 3
# new_annotations: 116
#
#   Loaded!
#
#  FILE < 5 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 5
# new_categories: 3
# new_annotations: 130
#
#   Loaded!
#
#  FILE < 6 > details:
# info: 1
# images: 1
# annotations: 11
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 6
# new_categories: 3
# new_annotations: 141
#
#   Loaded!
#
#  FILE < 7 > details:
# info: 1
# images: 1
# annotations: 17
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 7
# new_categories: 3
# new_annotations: 158
#
#   Loaded!
#
#  FILE < 8 > details:
# info: 1
# images: 1
# annotations: 89
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 8
# new_categories: 3
# new_annotations: 247
#
#   Loaded!
#
#  FILE < 9 > details:
# info: 1
# images: 1
# annotations: 68
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 9
# new_categories: 3
# new_annotations: 315
#
#   Loaded!
#
#  FILE < 10 > details:
# info: 1
# images: 1
# annotations: 41
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 10
# new_categories: 3
# new_annotations: 356
#
#   Loaded!
#
#  FILE < 11 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 11
# new_categories: 3
# new_annotations: 416
#
#   Loaded!
#
#  FILE < 12 > details:
# info: 1
# images: 1
# annotations: 29
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 12
# new_categories: 3
# new_annotations: 445
#
#   Loaded!
#
#  FILE < 13 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 13
# new_categories: 3
# new_annotations: 490
#
#   Loaded!
#
#  FILE < 14 > details:
# info: 1
# images: 1
# annotations: 53
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 14
# new_categories: 3
# new_annotations: 543
#
#   Loaded!
#
#  FILE < 15 > details:
# info: 1
# images: 1
# annotations: 28
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 15
# new_categories: 3
# new_annotations: 571
#
#   Loaded!
#
#  FILE < 16 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 16
# new_categories: 3
# new_annotations: 591
#
#   Loaded!
#
#  FILE < 17 > details:
# info: 1
# images: 1
# annotations: 13
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 17
# new_categories: 3
# new_annotations: 604
#
#   Loaded!
#
#  FILE < 18 > details:
# info: 1
# images: 1
# annotations: 42
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 18
# new_categories: 3
# new_annotations: 646
#
#   Loaded!
#
#  FILE < 19 > details:
# info: 1
# images: 1
# annotations: 30
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 19
# new_categories: 3
# new_annotations: 676
#
#   Loaded!
#
#  FILE < 20 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 20
# new_categories: 3
# new_annotations: 711
#
#   Loaded!
#
#  FILE < 21 > details:
# info: 1
# images: 1
# annotations: 25
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 21
# new_categories: 3
# new_annotations: 736
#
#   Loaded!
#
#  FILE < 22 > details:
# info: 1
# images: 1
# annotations: 19
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 22
# new_categories: 3
# new_annotations: 755
#
#   Loaded!
#
#  FILE < 23 > details:
# info: 1
# images: 1
# annotations: 13
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 23
# new_categories: 3
# new_annotations: 768
#
#   Loaded!
#
#  FILE < 24 > details:
# info: 1
# images: 1
# annotations: 17
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 24
# new_categories: 3
# new_annotations: 785
#
#   Loaded!
#
#  FILE < 25 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 25
# new_categories: 3
# new_annotations: 793
#
#   Loaded!
#
#  FILE < 26 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 26
# new_categories: 3
# new_annotations: 811
#
#   Loaded!
#
#  FILE < 27 > details:
# info: 1
# images: 1
# annotations: 3
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 27
# new_categories: 3
# new_annotations: 814
#
#   Loaded!
#
#  FILE < 28 > details:
# info: 1
# images: 1
# annotations: 12
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 28
# new_categories: 3
# new_annotations: 826
#
#   Loaded!
#
#  FILE < 29 > details:
# info: 1
# images: 1
# annotations: 11
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 29
# new_categories: 3
# new_annotations: 837
#
#   Loaded!
#
#  FILE < 30 > details:
# info: 1
# images: 1
# annotations: 91
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 30
# new_categories: 3
# new_annotations: 928
#
#   Loaded!
#
#  FILE < 31 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 31
# new_categories: 3
# new_annotations: 942
#
#   Loaded!
#
#  FILE < 32 > details:
# info: 1
# images: 1
# annotations: 61
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 32
# new_categories: 3
# new_annotations: 1003
#
#   Loaded!
#
#  FILE < 33 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 33
# new_categories: 3
# new_annotations: 1038
#
#   Loaded!
#
#  FILE < 34 > details:
# info: 1
# images: 1
# annotations: 30
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 34
# new_categories: 3
# new_annotations: 1068
#
#   Loaded!
#
#  FILE < 35 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 35
# new_categories: 3
# new_annotations: 1113
#
#   Loaded!
#
#  FILE < 36 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 36
# new_categories: 3
# new_annotations: 1119
#
#   Loaded!
#
#  FILE < 37 > details:
# info: 1
# images: 1
# annotations: 21
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 37
# new_categories: 3
# new_annotations: 1140
#
#   Loaded!
#
#  FILE < 38 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 38
# new_categories: 3
# new_annotations: 1146
#
#   Loaded!
#
#  FILE < 39 > details:
# info: 1
# images: 1
# annotations: 19
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 39
# new_categories: 3
# new_annotations: 1165
#
#   Loaded!
#
#  FILE < 40 > details:
# info: 1
# images: 1
# annotations: 28
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 40
# new_categories: 3
# new_annotations: 1193
#
#   Loaded!
#
#  FILE < 41 > details:
# info: 1
# images: 1
# annotations: 9
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 41
# new_categories: 3
# new_annotations: 1202
#
#   Loaded!
#
#  FILE < 42 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 42
# new_categories: 3
# new_annotations: 1208
#
#   Loaded!
#
#  FILE < 43 > details:
# info: 1
# images: 1
# annotations: 26
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 43
# new_categories: 3
# new_annotations: 1234
#
#   Loaded!
#
#  FILE < 44 > details:
# info: 1
# images: 1
# annotations: 19
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 44
# new_categories: 3
# new_annotations: 1253
#
#   Loaded!
#
#  FILE < 45 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 45
# new_categories: 3
# new_annotations: 1313
#
#   Loaded!
#
#  FILE < 46 > details:
# info: 1
# images: 1
# annotations: 11
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 46
# new_categories: 3
# new_annotations: 1324
#
#   Loaded!
#
#  FILE < 47 > details:
# info: 1
# images: 1
# annotations: 25
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 47
# new_categories: 3
# new_annotations: 1349
#
#   Loaded!
#
#  FILE < 48 > details:
# info: 1
# images: 1
# annotations: 51
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 48
# new_categories: 3
# new_annotations: 1400
#
#   Loaded!
#
#  FILE < 49 > details:
# info: 1
# images: 1
# annotations: 71
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 49
# new_categories: 3
# new_annotations: 1471
#
#   Loaded!
#
#  FILE < 50 > details:
# info: 1
# images: 1
# annotations: 36
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 50
# new_categories: 3
# new_annotations: 1507
#
#   Loaded!
#
#  FILE < 51 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 51
# new_categories: 3
# new_annotations: 1513
#
#   Loaded!
#
#  FILE < 52 > details:
# info: 1
# images: 1
# annotations: 4
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 52
# new_categories: 3
# new_annotations: 1517
#
#   Loaded!
#
#  FILE < 53 > details:
# info: 1
# images: 1
# annotations: 15
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 53
# new_categories: 3
# new_annotations: 1532
#
#   Loaded!
#
#  FILE < 54 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 54
# new_categories: 3
# new_annotations: 1548
#
#   Loaded!
#
#  FILE < 55 > details:
# info: 1
# images: 1
# annotations: 55
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 55
# new_categories: 3
# new_annotations: 1603
#
#   Loaded!
#
#  FILE < 56 > details:
# info: 1
# images: 1
# annotations: 24
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 56
# new_categories: 3
# new_annotations: 1627
#
#   Loaded!
#
#  FILE < 57 > details:
# info: 1
# images: 1
# annotations: 123
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 57
# new_categories: 3
# new_annotations: 1750
#
#   Loaded!
#
#  FILE < 58 > details:
# info: 1
# images: 1
# annotations: 121
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 58
# new_categories: 3
# new_annotations: 1871
#
#   Loaded!
#
#  FILE < 59 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 59
# new_categories: 3
# new_annotations: 1906
#
#   Loaded!
#
#  FILE < 60 > details:
# info: 1
# images: 1
# annotations: 61
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 60
# new_categories: 3
# new_annotations: 1967
#
#   Loaded!
#
#  FILE < 61 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 61
# new_categories: 3
# new_annotations: 1981
#
#   Loaded!
#
#  FILE < 62 > details:
# info: 1
# images: 1
# annotations: 22
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 62
# new_categories: 3
# new_annotations: 2003
#
#   Loaded!
#
#  FILE < 63 > details:
# info: 1
# images: 1
# annotations: 53
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 63
# new_categories: 3
# new_annotations: 2056
#
#   Loaded!
#
#  FILE < 64 > details:
# info: 1
# images: 1
# annotations: 15
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 64
# new_categories: 3
# new_annotations: 2071
#
#   Loaded!
#
#  FILE < 65 > details:
# info: 1
# images: 1
# annotations: 12
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 65
# new_categories: 3
# new_annotations: 2083
#
#   Loaded!
#
#  FILE < 66 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 66
# new_categories: 3
# new_annotations: 2128
#
#   Loaded!
#
#  FILE < 67 > details:
# info: 1
# images: 1
# annotations: 55
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 67
# new_categories: 3
# new_annotations: 2183
#
#   Loaded!
#
#  FILE < 68 > details:
# info: 1
# images: 1
# annotations: 55
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 68
# new_categories: 3
# new_annotations: 2238
#
#   Loaded!
#
#  FILE < 69 > details:
# info: 1
# images: 1
# annotations: 46
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 69
# new_categories: 3
# new_annotations: 2284
#
#   Loaded!
#
#  FILE < 70 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 70
# new_categories: 3
# new_annotations: 2292
#
#   Loaded!
#
#  FILE < 71 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 71
# new_categories: 3
# new_annotations: 2306
#
#   Loaded!
#
#  FILE < 72 > details:
# info: 1
# images: 1
# annotations: 5
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 72
# new_categories: 3
# new_annotations: 2311
#
#   Loaded!
#
#  FILE < 73 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 73
# new_categories: 3
# new_annotations: 2327
#
#   Loaded!
#
#  FILE < 74 > details:
# info: 1
# images: 1
# annotations: 25
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 74
# new_categories: 3
# new_annotations: 2352
#
#   Loaded!
#
#  FILE < 75 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 75
# new_categories: 3
# new_annotations: 2370
#
#   Loaded!
#
#  FILE < 76 > details:
# info: 1
# images: 1
# annotations: 28
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 76
# new_categories: 3
# new_annotations: 2398
#
#   Loaded!
#
#  FILE < 77 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 77
# new_categories: 3
# new_annotations: 2406
#
#   Loaded!
#
#  FILE < 78 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 78
# new_categories: 3
# new_annotations: 2412
#
#   Loaded!
#
#  FILE < 79 > details:
# info: 1
# images: 1
# annotations: 13
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 79
# new_categories: 3
# new_annotations: 2425
#
#   Loaded!
#
#  FILE < 80 > details:
# info: 1
# images: 1
# annotations: 36
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 80
# new_categories: 3
# new_annotations: 2461
#
#   Loaded!
#
#  FILE < 81 > details:
# info: 1
# images: 1
# annotations: 9
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 81
# new_categories: 3
# new_annotations: 2470
#
#   Loaded!
#
#  FILE < 82 > details:
# info: 1
# images: 1
# annotations: 10
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 82
# new_categories: 3
# new_annotations: 2480
#
#   Loaded!
#
#  FILE < 83 > details:
# info: 1
# images: 1
# annotations: 5
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 83
# new_categories: 3
# new_annotations: 2485
#
#   Loaded!
#
#  FILE < 84 > details:
# info: 1
# images: 1
# annotations: 4
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 84
# new_categories: 3
# new_annotations: 2489
#
#   Loaded!
#
#  FILE < 85 > details:
# info: 1
# images: 1
# annotations: 7
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 85
# new_categories: 3
# new_annotations: 2496
#     Location:  ./
#  Output file:  custom_multy_coco_28_13_32_1.json

# %% [markdown]
# # COUNT FILES AND UPDATE IDs
# # EXTRACT BBOX VALUES FROM POLY VALUES
# # MERGE MULTY JSON FILES INTO ONE

# %%
import datetime
import json
import os

data_path = './DATA/testData/train/'
# data_path = './DATA/testData/valid/'
# data_path = './DATA/testData/'
# data_path = './DATA/'
#new_json_path = './out/'
new_json_path = './'
file_format = '.json'
new_json_file = 'custom_multy_coco'

class JsonAnt:
    
        # LOAD DATA
    def __init__(self):
        
        self.createDict()

    def createDict(self):
        print('Creating dict')
        jsonAnt = {"info": [        {
            "contributor": "Konkuk_university",
            "date_created": "2021/05/21",
            "description": "PGON JSON file",
            "url": "",
            "version": "1.0",
            "year": 2021
        }],
           "images": [],
           "annotations": [],
           "categories": [
            {
                "id": 1,
                "name": "Building, Overpass, Bridge"
            },
            {
                "id": 2,
                "name": "Road Marking, Lane Marking"
            },
            {
                "id": 3,
                "name": "Guard Rail, Fence, Soundproof Wall"
            }]
          }
        return jsonAnt
        

    
    def write_json(self, jsonAnt, loaded_json, num_found_files):
        
        source_infos = loaded_json['info']
        source_images = loaded_json['images']
        source_images['id'] = num_found_files
#         print(f'source_images id : {source_images['id']}')

        source_categories = loaded_json['categories']
        source_annotations = loaded_json['annotations']
        for _ in source_annotations:
            seg_list_b = _['segmentation'][0]
#             print(seg)
            xcoords, ycoords = [], []
            for i in range(0, len(seg_list_b), 2):
                xcoords.append(seg_list_b[i])
            for i in range(1, len(seg_list_b), 2):
                ycoords.append(seg_list_b[i])
            xmax, ymin = float(max(xcoords)), float(min(ycoords))
            ymax, xmin = float(max(ycoords)), float(min(xcoords))
            poly_bbox = [xmax, ymin, ymax, xmin]
            width, height = xmax - xmin, ymax - ymin
            bboxx = [xmin, ymin, width, height]
            seg_list_b = _['bbox']
#         for _ in source_annotations:
            _['bbox'] = bboxx
            _['image_id'] = num_found_files


        print('\n FILE < ' + str(num_found_files) + ' > details: ')
        source_infos_l = []
        source_infos_l.append(source_infos)
        print('info: ' + str(len(source_infos_l)))
        source_images_l = []
        source_images_l.append(source_images)
        print('images: ' + str(len(source_images_l)))
        print('annotations: ' + str(len(source_annotations)))
        print('categories: ' + str(len(source_categories)))

        file_desc = source_infos['description']
        print(f'file type is :{file_desc[33:47]}')
        
        
        new_source_infos = jsonAnt['info']
        new_source_images = jsonAnt['images']
        new_source_categories = jsonAnt['categories']
        new_source_annotations = jsonAnt['annotations']
        
        
#         new_source_infos.append(source_infos)
#         jsonAnt['info'] = new_source_infos
        print('\n After merging the new file')
        print('new_info: ' + str(len(new_source_infos)))  

        new_source_images.append(source_images)
        jsonAnt['images'] = new_source_images
        print('new_images: ' + str(len(new_source_images)))
        tli = int(len(new_source_images))
        for ai, bi in zip(range(tli), new_source_images):
            bi['id'] = ai+1
            
#         new_source_categories.append(source_categories)
#         jsonAnt['categories'] = new_source_categories
        print('new_categories: ' + str(len(new_source_categories)))


        for i in source_annotations:
            new_source_annotations.append(i)
        jsonAnt['annotations'] = new_source_annotations
        print('new_annotations: ' + str(len(new_source_annotations)))
        tl = int(len(new_source_annotations))
        for a, b in zip(range(tl), new_source_annotations):
            b['id'] = a+1
            
#         for a, b in zip(range(tl), new_source_annotations):
#             b['image_id'] = a+1
    
        return jsonAnt

        
        
        
# RUN THE PROGRAM
def main():
    
    callClass = JsonAnt()
    
    json_Ant  = callClass.createDict()

    
    
    num_found_files = 0
    print(' Loading Coco json')
    for file in os.listdir(data_path):
        
        try:
            if 'json' in file:
                num_found_files = num_found_files + 1
                json_path = os.path.join(data_path, file)
                with open(json_path) as f:
                    loaded_json = json.load(f)
#                     print(f'loaded json11 {loaded_json}')
                print('\n  Loaded!')
#                 box_v  = callClass.poly_to_bbox(loaded_json)
                callClass.write_json(json_Ant, loaded_json, num_found_files)
#                 print('\n FILE < ' + str(num_found_files) + ' > details: ')
        except:
            if 'json' not in file:
                print(' Finished, nothing to load')
                return



    

    now = datetime.datetime.now()        # creating new file name with date attached
    currentDate = "_" + str(now.day) + "_" + str(now.hour) + "_" + str(now.minute) + "_" + str(now.second)
    file_output = os.path.join(new_json_file + currentDate + file_format)
    with open(new_json_path + file_output, 'a+') as outfile:
        json.dump(json_Ant, outfile, sort_keys=True, indent=4, )  # , indent=4, im.__dict__
        outfile.write('\n')
        outfile.close()
    print(f'    Location:  {new_json_path}  \n Output file:  {file_output} \n')
    
    
if __name__ == '__main__':
    main()
# Out:
# Creating dict
# Creating dict
#  Loading Coco json
#
#   Loaded!
#
#  FILE < 1 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 1
# new_categories: 3
# new_annotations: 45
#
#   Loaded!
#
#  FILE < 2 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 2
# new_categories: 3
# new_annotations: 105
#
#   Loaded!
#
#  FILE < 3 > details:
# info: 1
# images: 1
# annotations: 47
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 3
# new_categories: 3
# new_annotations: 152
#
#   Loaded!
#
#  FILE < 4 > details:
# info: 1
# images: 1
# annotations: 31
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 4
# new_categories: 3
# new_annotations: 183
#
#   Loaded!
#
#  FILE < 5 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 5
# new_categories: 3
# new_annotations: 199
#
#   Loaded!
#
#  FILE < 6 > details:
# info: 1
# images: 1
# annotations: 14
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 6
# new_categories: 3
# new_annotations: 213
#
#   Loaded!
#
#  FILE < 7 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 7
# new_categories: 3
# new_annotations: 231
#
#   Loaded!
#
#  FILE < 8 > details:
# info: 1
# images: 1
# annotations: 96
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 8
# new_categories: 3
# new_annotations: 327
#
#   Loaded!
#
#  FILE < 9 > details:
# info: 1
# images: 1
# annotations: 82
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 9
# new_categories: 3
# new_annotations: 409
#
#   Loaded!
#
#  FILE < 10 > details:
# info: 1
# images: 1
# annotations: 52
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 10
# new_categories: 3
# new_annotations: 461
#
#   Loaded!
#
#  FILE < 11 > details:
# info: 1
# images: 1
# annotations: 71
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 11
# new_categories: 3
# new_annotations: 532
#
#   Loaded!
#
#  FILE < 12 > details:
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 12
# new_categories: 3
# new_annotations: 577
#
#   Loaded!
#
#  FILE < 13 > details:
# info: 1
# images: 1
# annotations: 54
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 13
# new_categories: 3
# new_annotations: 631
#
#   Loaded!
#
#  FILE < 14 > details:
# info: 1
# images: 1
# annotations: 56
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 14
# new_categories: 3
# new_annotations: 687
#
#   Loaded!
#
#  FILE < 15 > details:
# info: 1
# images: 1
# annotations: 39
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 15
# new_categories: 3
# new_annotations: 726
#
#   Loaded!
#
#  FILE < 16 > details:
# info: 1
# images: 1
# annotations: 32
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 16
# new_categories: 3
# new_annotations: 758
#
#   Loaded!
#
#  FILE < 17 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 17
# new_categories: 3
# new_annotations: 778
#
#   Loaded!
#
#  FILE < 18 > details:
# info: 1
# images: 1
# annotations: 46
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 18
# new_categories: 3
# new_annotations: 824
#
#   Loaded!
#
#  FILE < 19 > details:
# info: 1
# images: 1
# annotations: 34
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 19
# new_categories: 3
# new_annotations: 858
#
#   Loaded!
#
#  FILE < 20 > details:
# info: 1
# images: 1
# annotations: 55
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 20
# new_categories: 3
# new_annotations: 913
#
#   Loaded!
#
#  FILE < 21 > details:
# info: 1
# images: 1
# annotations: 41
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 21
# new_categories: 3
# new_annotations: 954
#
#   Loaded!
#
#  FILE < 22 > details:
# info: 1
# images: 1
# annotations: 31
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 22
# new_categories: 3
# new_annotations: 985
#
#   Loaded!
#
#  FILE < 23 > details:
# info: 1
# images: 1
# annotations: 21
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 23
# new_categories: 3
# new_annotations: 1006
#
#   Loaded!
#
#  FILE < 24 > details:
# info: 1
# images: 1
# annotations: 26
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 24
# new_categories: 3
# new_annotations: 1032
#
#   Loaded!
#
#  FILE < 25 > details:
# info: 1
# images: 1
# annotations: 17
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 25
# new_categories: 3
# new_annotations: 1049
#
#   Loaded!
#
#  FILE < 26 > details:
# info: 1
# images: 1
# annotations: 29
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 26
# new_categories: 3
# new_annotations: 1078
#
#   Loaded!
#
#  FILE < 27 > details:
# info: 1
# images: 1
# annotations: 6
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 27
# new_categories: 3
# new_annotations: 1084
#
#   Loaded!
#
#  FILE < 28 > details:
# info: 1
# images: 1
# annotations: 13
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 28
# new_categories: 3
# new_annotations: 1097
#
#   Loaded!
#
#  FILE < 29 > details:
# info: 1
# images: 1
# annotations: 22
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 29
# new_categories: 3
# new_annotations: 1119
#
#   Loaded!
#
#  FILE < 30 > details:
# info: 1
# images: 1
# annotations: 92
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 30
# new_categories: 3
# new_annotations: 1211
#
#   Loaded!
#
#  FILE < 31 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 31
# new_categories: 3
# new_annotations: 1231
#
#   Loaded!
#
#  FILE < 32 > details:
# info: 1
# images: 1
# annotations: 77
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 32
# new_categories: 3
# new_annotations: 1308
#
#   Loaded!
#
#  FILE < 33 > details:
# info: 1
# images: 1
# annotations: 39
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 33
# new_categories: 3
# new_annotations: 1347
#
#   Loaded!
#
#  FILE < 34 > details:
# info: 1
# images: 1
# annotations: 41
# categories: 3
# file type is :_PGON JSON fil
#
#  After merging the new file
# new_info: 1
# new_images: 34
# new_categories: 3
# new_annotations: 1388
#
#   Loaded!
#
#  FILE < 35 > details:
# info: 1
# images: 1
# annotations: 48
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 35
# new_categories: 3
# new_annotations: 1436
#
#   Loaded!
#
#  FILE < 36 > details:
# info: 1
# images: 1
# annotations: 7
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 36
# new_categories: 3
# new_annotations: 1443
#
#   Loaded!
#
#  FILE < 37 > details:
# info: 1
# images: 1
# annotations: 24
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 37
# new_categories: 3
# new_annotations: 1467
#
#   Loaded!
#
#  FILE < 38 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 38
# new_categories: 3
# new_annotations: 1475
#
#   Loaded!
#
#  FILE < 39 > details:
# info: 1
# images: 1
# annotations: 19
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 39
# new_categories: 3
# new_annotations: 1494
#
#   Loaded!
#
#  FILE < 40 > details:
# info: 1
# images: 1
# annotations: 36
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 40
# new_categories: 3
# new_annotations: 1530
#
#   Loaded!
#
#  FILE < 41 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 41
# new_categories: 3
# new_annotations: 1550
#
#   Loaded!
#
#  FILE < 42 > details:
# info: 1
# images: 1
# annotations: 17
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 42
# new_categories: 3
# new_annotations: 1567
#
#   Loaded!
#
#  FILE < 43 > details:
# info: 1
# images: 1
# annotations: 31
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 43
# new_categories: 3
# new_annotations: 1598
#
#   Loaded!
#
#  FILE < 44 > details:
# info: 1
# images: 1
# annotations: 37
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 44
# new_categories: 3
# new_annotations: 1635
#
#   Loaded!
#
#  FILE < 45 > details:
# info: 1
# images: 1
# annotations: 66
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 45
# new_categories: 3
# new_annotations: 1701
#
#   Loaded!
#
#  FILE < 46 > details:
# info: 1
# images: 1
# annotations: 26
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 46
# new_categories: 3
# new_annotations: 1727
#
#   Loaded!
#
#  FILE < 47 > details:
# info: 1
# images: 1
# annotations: 48
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 47
# new_categories: 3
# new_annotations: 1775
#
#   Loaded!
#
#  FILE < 48 > details:
# info: 1
# images: 1
# annotations: 57
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 48
# new_categories: 3
# new_annotations: 1832
#
#   Loaded!
#
#  FILE < 49 > details:
# info: 1
# images: 1
# annotations: 83
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 49
# new_categories: 3
# new_annotations: 1915
#
#   Loaded!
#
#  FILE < 50 > details:
# info: 1
# images: 1
# annotations: 38
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 50
# new_categories: 3
# new_annotations: 1953
#
#   Loaded!
#
#  FILE < 51 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 51
# new_categories: 3
# new_annotations: 1969
#
#   Loaded!
#
#  FILE < 52 > details:
# info: 1
# images: 1
# annotations: 23
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 52
# new_categories: 3
# new_annotations: 1992
#
#   Loaded!
#
#  FILE < 53 > details:
# info: 1
# images: 1
# annotations: 28
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 53
# new_categories: 3
# new_annotations: 2020
#
#   Loaded!
#
#  FILE < 54 > details:
# info: 1
# images: 1
# annotations: 27
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 54
# new_categories: 3
# new_annotations: 2047
#
#   Loaded!
#
#  FILE < 55 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 55
# new_categories: 3
# new_annotations: 2107
#
#   Loaded!
#
#  FILE < 56 > details:
# info: 1
# images: 1
# annotations: 38
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 56
# new_categories: 3
# new_annotations: 2145
#
#   Loaded!
#
#  FILE < 57 > details:
# info: 1
# images: 1
# annotations: 150
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 57
# new_categories: 3
# new_annotations: 2295
#
#   Loaded!
#
#  FILE < 58 > details:
# info: 1
# images: 1
# annotations: 149
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 58
# new_categories: 3
# new_annotations: 2444
#
#   Loaded!
#
#  FILE < 59 > details:
# info: 1
# images: 1
# annotations: 50
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 59
# new_categories: 3
# new_annotations: 2494
#
#   Loaded!
#
#  FILE < 60 > details:
# info: 1
# images: 1
# annotations: 64
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 60
# new_categories: 3
# new_annotations: 2558
#
#   Loaded!
#
#  FILE < 61 > details:
# info: 1
# images: 1
# annotations: 24
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 61
# new_categories: 3
# new_annotations: 2582
#
#   Loaded!
#
#  FILE < 62 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 62
# new_categories: 3
# new_annotations: 2617
#
#   Loaded!
#
#  FILE < 63 > details:
# info: 1
# images: 1
# annotations: 65
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 63
# new_categories: 3
# new_annotations: 2682
#
#   Loaded!
#
#  FILE < 64 > details:
# info: 1
# images: 1
# annotations: 26
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 64
# new_categories: 3
# new_annotations: 2708
#
#   Loaded!
#
#  FILE < 65 > details:
# info: 1
# images: 1
# annotations: 18
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 65
# new_categories: 3
# new_annotations: 2726
#
#   Loaded!
#
#  FILE < 66 > details:
# info: 1
# images: 1
# annotations: 60
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 66
# new_categories: 3
# new_annotations: 2786
#
#   Loaded!
#
#  FILE < 67 > details:
# info: 1
# images: 1
# annotations: 70
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 67
# new_categories: 3
# new_annotations: 2856
#   Loaded!
#
#  FILE < 68 > details:
# info: 1
# images: 1
# annotations: 69
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 68
# new_categories: 3
# new_annotations: 2925
#
#   Loaded!
#
#  FILE < 69 > details:
# info: 1
# images: 1
# annotations: 49
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 69
# new_categories: 3
# new_annotations: 2974
#
#   Loaded!
#
#  FILE < 70 > details:
# info: 1
# images: 1
# annotations: 15
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 70
# new_categories: 3
# new_annotations: 2989
#
#   Loaded!
#
#  FILE < 71 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 71
# new_categories: 3
# new_annotations: 3024
#
#   Loaded!
#
#  FILE < 72 > details:
# info: 1
# images: 1
# annotations: 15
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 72
# new_categories: 3
# new_annotations: 3039
#
#   Loaded!
#
#  FILE < 73 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 73
# new_categories: 3
# new_annotations: 3059
#
#   Loaded!
#
#  FILE < 74 > details:
# info: 1
# images: 1
# annotations: 33
# categories: 3
# file type is :GON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 74
# new_categories: 3
# new_annotations: 3092
#
#   Loaded!
#
#  FILE < 75 > details:
# info: 1
# images: 1
# annotations: 20
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 75
# new_categories: 3
# new_annotations: 3112
#
#   Loaded!
#
#  FILE < 76 > details:
# info: 1
# images: 1
# annotations: 35
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 76
# new_categories: 3
# new_annotations: 3147
#
#   Loaded!
#
#  FILE < 77 > details:
# info: 1
# images: 1
# annotations: 9
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 77
# new_categories: 3
# new_annotations: 3156
#
#   Loaded!
#
#  FILE < 78 > details:
# info: 1
# images: 1
# annotations: 7
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 78
# new_categories: 3
# new_annotations: 3163
#
#   Loaded!
#
#  FILE < 79 > details:
# info: 1
# images: 1
# annotations: 21
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 79
# new_categories: 3
# new_annotations: 3184
#
#   Loaded!
#
#  FILE < 80 > details:
# info: 1
# images: 1
# annotations: 44
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 80
# new_categories: 3
# new_annotations: 3228
#
#   Loaded!
#
#  FILE < 81 > details:
# info: 1
# images: 1
# annotations: 12
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 81
# new_categories: 3
# new_annotations: 3240
#
#   Loaded!
#
#  FILE < 82 > details:
# info: 1
# images: 1
# annotations: 16
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 82
# new_categories: 3
# new_annotations: 3256
#
#   Loaded!
#
#  FILE < 83 > details:
# info: 1
# images: 1
# annotations: 10
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 83
# new_categories: 3
# new_annotations: 3266
#
#   Loaded!
#
#  FILE < 84 > details:
# info: 1
# images: 1
# annotations: 5
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 84
# new_categories: 3
# new_annotations: 3271
#
#   Loaded!
#
#  FILE < 85 > details:
# info: 1
# images: 1
# annotations: 8
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 85
# new_categories: 3
# new_annotations: 3279
#     Location:  ./
#  Output file:  custom_multy_coco_28_13_30_44.json

# %% [markdown]
# # EXTRACT BBOX VALUES FROM POLY VALUES AND MERGE MULTY JSON FILES INTO ONE

# %%
import datetime
import json
import os

data_path = './DATA/'
json_file = 'custom_multy_coco.json'
#new_json_path = './out/'
new_json_path = './'
file_format = '.json'
new_json_file = 'custom_multy_coco'

class JsonAnt:
    

    
        # LOAD DATA
    def __init__(self):
        
        self.createDict()

    def createDict(self):
        print('Creating dict')
        jsonAnt = {"info": [        {
            "contributor": "Konkuk_university",
            "date_created": "2021/05/21",
            "description": "PGON JSON file",
            "url": "",
            "version": "1.0",
            "year": 2021
        }],
           "images": [],
           "annotations": [],
           "categories": [
            {
                "id": 1,
                "name": "Building, Overpass, Bridge"
            },
            {
                "id": 2,
                "name": "Road Marking, Lane Marking"
            },
            {
                "id": 3,
                "name": "Guard Rail, Fence, Soundproof Wall"
            }]
          }
        return jsonAnt
        

    
    def write_json(self, jsonAnt, loaded_json, num_found_files):
        
        source_infos = loaded_json['info']
        source_images = loaded_json['images']
        source_categories = loaded_json['categories']
        source_annotations = loaded_json['annotations']
        for _ in source_annotations:
            seg_list_b = _['segmentation'][0]
#             for se_ in seg_list_b
#             print(f'seg_list_b {seg_list_b} ')
            xcoords, ycoords = [], []
            for i in range(0, len(seg_list_b), 2):
                xcoords.append(seg_list_b[i])
            for i in range(1, len(seg_list_b), 2):
                ycoords.append(seg_list_b[i])
            xmax, ymin = float(max(xcoords)), float(min(ycoords))
            ymax, xmin = float(max(ycoords)), float(min(xcoords))
            poly_bbox = [xmax, ymin, ymax, xmin]
            width, height = xmax - xmin, ymax - ymin
            bboxx = [xmin, ymin, width, height]
            seg_list_b = _['bbox']
#             for _ in source_annotations:
            _['bbox'] = bboxx
#             print(f'bboxx {bboxx} ')


#             print(bboxx)

        
#         print('\n FILE < ' + str(num_found_files) + ' > details: ')
        source_infos_l = []
        source_infos_l.append(source_infos)
        print('info: ' + str(len(source_infos_l)))
        source_images_l = []
        source_images_l.append(source_images)
        print('images: ' + str(len(source_images_l)))
        print('annotations: ' + str(len(source_annotations)))
        print('categories: ' + str(len(source_categories)))

        file_desc = source_infos['description']
        print(f'file type is :{file_desc[33:47]}')
        
        
        new_source_infos = jsonAnt['info']
        new_source_images = jsonAnt['images']
        new_source_categories = jsonAnt['categories']
        new_source_annotations = jsonAnt['annotations']


        
        
#         new_source_infos.append(source_infos)
#         jsonAnt['info'] = new_source_infos
        new_source_images.append(source_images)
        jsonAnt['images'] = new_source_images
#         new_source_categories.append(source_categories)
#         jsonAnt['categories'] = new_source_categories
        for i in source_annotations:
            new_source_annotations.append(i)
        jsonAnt['annotations'] = new_source_annotations
        print('\n After merging the new file')
        print('new_info: ' + str(len(new_source_infos)))        
        print('new_images: ' + str(len(new_source_images)))
        print('new_annotations: ' + str(len(new_source_annotations)))
        print('new_categories: ' + str(len(new_source_categories)))
#         print('NEW jsonAnt: ' + str(jsonAnt))
        return jsonAnt

        
        
        
# RUN THE PROGRAM
def main():
    
    callClass = JsonAnt()
    
    json_Ant  = callClass.createDict()

    
    
    num_found_files = []
    print(' Loading Coco json')
    for file in os.listdir(data_path):
        
        try:
            if 'json' in file:
                num_found_files =+ 1
                json_path = os.path.join(data_path, file)
                with open(json_path) as f:
                    loaded_json = json.load(f)
#                     print(f'loaded json11 {loaded_json}')
                print('\n  Loaded!')
#                 box_v  = callClass.poly_to_bbox(loaded_json)
                callClass.write_json(json_Ant, loaded_json, num_found_files)
#                 print('\n FILE < ' + str(num_found_files) + ' > details: ')
        except:
            if 'json' not in file:
                print(' Finished, nothing to load')
                return



    

    now = datetime.datetime.now()        # creating new file name with date attached
    currentDate = "_" + str(now.day) + "_" + str(now.hour) + "_" + str(now.minute) + "_" + str(now.second)
    file_output = os.path.join(new_json_file + currentDate + file_format)
    with open(new_json_path + file_output, 'a+') as outfile:
        json.dump(json_Ant, outfile, sort_keys=True, indent=4, )  # , indent=4, im.__dict__
        outfile.write('\n')
        outfile.close()
    print(f'    Location:  {new_json_path}  \n Output file:  {file_output} \n')
    
    
if __name__ == '__main__':
    main()
# Out:
# Creating dict
# Creating dict
#  Loading Coco json
#
#   Loaded!
# bboxx [0.0, 586.473092761918, 592.5036644098554, 197.50122146995182]
# bboxx [609.1158827157033, 572.1814206424847, 25.127543869484725, 8.174020294892557]
# bboxx [636.362617032012, 584.2910803386219, 143.19672590682285, 32.3933396871671]
# bboxx [810.7749661838936, 518.4256540529841, 79.2781498465904, 15.855629969318102]
# bboxx [928.7921856426688, 526.6318672799628, 13.954209519872052, 8.372525711923117]
# bboxx [899.7674298413356, 550.6331076541423, 22.884903612589596, 11.163367615897528]
# bboxx [856.5093803297328, 584.1232105018347, 34.04827122848724, 20.37314589901291]
# bboxx [751.8528089306941, 651.6615845780144, 72.00372112253865, 51.63057522352574]
# bboxx [373.41464675177014, 849.8113597601944, 270.9907488759109, 229.40720450669278]
# bboxx [1448.2721479220895, 847.7335966250786, 293.2411812225116, 232.26640337492142]
# bboxx [1674.7222037394374, 655.3729456384325, 186.47947301883028, 56.410938851553624]
# bboxx [1460.6900323595096, 578.6153776035733, 81.7100405633289, 25.349801741032707]
# bboxx [1278.3191285720798, 575.4158880634429, 148.6532063260563, 33.47158288136359]
# bboxx [1238.9407957704757, 648.2658037464108, 69.65042614283743, 43.56228066177482]
# bboxx [1167.563019973203, 579.9956376779984, 32.30611036674668, 19.68653600473624]
# bboxx [954.5446047424672, 578.4812887545571, 147.06010656529463, 30.62350045181188]
# bboxx [1130.4360349980195, 544.8025060310373, 20.22107802542064, 11.471573110575036]
# bboxx [1108.270622547078, 524.775861448169, 16.915709502034588, 6.22187016166788]
# bboxx [1094.854715010982, 506.4991178482699, 32.859251791308, 10.110539012710149]
# bboxx [613.1903892394193, 569.9419666262904, 35.04781877677942, 3.2216657928515815]
# bboxx [765.1321885535161, 509.20095420223566, 28.105593123435142, 3.9390414604814055]
# bboxx [729.8937365692093, 510.9043234824439, 27.253908483330974, 4.471344360546425]
# bboxx [730.9583423693393, 507.28466376200146, 25.76346036314885, 3.9390414604814623]
# bboxx [693.1648364647201, 513.2464562427301, 32.36401632395564, 3.7261203004554773]
# bboxx [617.0019283466964, 517.0364356033696, 33.43144220034503, 3.617172434791428]
# bboxx [1588.5809383601102, 577.5715291557319, 146.55315880432704, 33.52749151891442]
# bboxx [1579.2485438136082, 541.2788836971132, 69.82013697753291, 15.55399091083666]
# bboxx [1740.741066326755, 577.4779130587666, 118.2013977407587, 22.548459408377653]
# bboxx [1806.5442745109824, 544.8514167242571, 113.4557254890176, 62.143565397674365]
# bboxx [1541.744538926114, 509.80439289684807, 378.25546107388595, 110.9822421201286]
# bboxx [0.0, 503.45910186690594, 610.3268486853171, 268.53170376184335]
# bboxx [168.96154039011182, 489.01368901368903, 66.88060973775262, 50.905079476508035]
# bboxx [0.0, 0.0, 700.6730317733607, 461.4806699013931]
# bboxx [691.6598432565214, 150.9650251491403, 108.64428588138969, 346.1457480407066]
# bboxx [797.9200111677254, 242.73050882948283, 46.36001954351923, 230.66936553360787]
# bboxx [837.495637607315, 340.7272981084666, 65.58246667131982, 105.5350038389056]
# bboxx [844.3151248970629, 400.5160581937963, 296.67966927591067, 71.94555430018858]
# bboxx [925.027461409493, 383.9972249523039, 124.2527605943227, 23.72665780193097]
# bboxx [1047.7192576747414, 369.9485459906342, 78.04821645372022, 55.88252298086377]
# bboxx [1123.8943169335723, 273.16875758802104, 25.912007862635164, 157.65739723651507]
# bboxx [1146.1932459414882, 162.67037069190036, 92.82055734004689, 281.2744161819603]
# bboxx [1215.1054779060685, 0.0, 234.63341431206368, 444.2448396882994]
# bboxx [1318.474612583018, 0.0, 312.3616367921163, 349.3822752267372]
# bboxx [1539.827179890024, 0.0, 177.7761908162538, 286.1386845675927]
# bboxx [1346.8826469067726, 290.7869833323158, 444.65529802271044, 143.74503937969354]
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 1
# new_annotations: 45
# new_categories: 3
#
#   Loaded!
# bboxx [259.14003009438693, 710.4464000729561, 1660.859969905613, 369.55359992704393]
# bboxx [0.0, 762.7913742317902, 428.0010182188443, 291.71594417594304]
# bboxx [0.0, 796.9267560485409, 16.11926628844735, 7.326939222021565]
# bboxx [0.0, 770.061312234462, 96.95982903808482, 17.58465413285171]
# bboxx [54.46358155035998, 747.592031953596, 111.12524486732644, 14.165415829241624]
# bboxx [97.69252296028696, 674.5668710407815, 257.6640293077569, 73.2693922202152]
# bboxx [178.28885440252373, 671.3918640445722, 242.27745694151167, 74.2463174498181]
# bboxx [977.0674823169566, 757.5759892945899, 153.42381953737345, 223.1619193270884]
# bboxx [1693.5786627074604, 765.5973275359244, 226.42133729253965, 112.49801155946761]
# bboxx [931.6090559234476, 632.3891412127725, 66.23444163228498, 32.95080262108661]
# bboxx [812.3301696228451, 633.0224964719555, 87.39588809872987, 31.876919671269206]
# bboxx [692.5260798583248, 632.7568554746949, 107.58460389053369, 32.14256066852977]
# bboxx [573.7845540828467, 635.4132654473007, 124.85126871247132, 30.283073687705837]
# bboxx [453.9804643183264, 635.4132654473007, 145.83690749605694, 35.06461163839617]
# bboxx [345.06765544148976, 639.3978804062093, 156.19690638921946, 34.53332964387505]
# bboxx [223.93536069066656, 646.0389053377238, 180.37023713993196, 34.79897064113561]
# bboxx [111.30357785218185, 648.1640333158084, 195.2461329865243, 35.86153463017786]
# bboxx [0.0, 652.9455712664987, 209.5907468385954, 35.86153463017797]
# bboxx [0.0, 655.0706992445834, 112.1005008439636, 24.43897174797314]
# bboxx [0.0, 655.8676222363652, 17.532305819198097, 6.109742936993257]
# bboxx [0.0, 626.9127535349622, 140.52408755084534, 25.501535737015388]
# bboxx [0.0, 629.3035225103074, 56.050250421981794, 11.156921884944268]
# bboxx [41.174354575389465, 625.5845485486593, 179.83895514541078, 26.564099726057748]
# bboxx [137.07075458645784, 622.3968565815323, 160.44716234538862, 28.423586706881792]
# bboxx [237.24261779891023, 620.2395771687447, 148.49703079403307, 27.035079484929497]
# bboxx [326.7718302961043, 617.496887945636, 135.56721017080588, 26.643266738771104]
# bboxx [418.2601065240904, 614.3623859763688, 128.12276799379623, 26.0555476195334]
# bboxx [513.0787910944227, 611.0319776340224, 116.36838560904437, 24.096483888741545]
# bboxx [613.3828541109727, 609.2688202763096, 98.34499928575804, 22.33332653102866]
# bboxx [706.0465685774341, 608.4851947839928, 91.09646348182764, 23.116952023345448]
# bboxx [805.3710997285881, 609.0729139032304, 74.44442177009569, 21.941513784870267]
# bboxx [906.0609251598344, 607.8435502068446, 57.76607747273408, 21.517863858593387]
# bboxx [997.7645731477998, 607.1214742384354, 49.53441143286943, 21.951109439638913]
# bboxx [1049.6096276795786, 632.1053027453929, 60.36555095900712, 32.2045881910492]
# bboxx [1089.757051523129, 607.2658894321172, 58.19932305377961, 21.951109439639026]
# bboxx [1149.256111320045, 632.5385483264384, 85.06054907860084, 32.2045881910492]
# bboxx [1173.084618277548, 608.7100413689355, 70.04136893568943, 20.940203083866095]
# bboxx [1250.779992478375, 633.1162091011657, 100.65738999623909, 33.359909740503895]
# bboxx [1256.989845806694, 608.9988717562993, 82.31666039864626, 22.673185408048084]
# bboxx [1350.2820609251596, 634.4159458443023, 126.21887927792409, 33.79315532154942]
# bboxx [1342.4836404663406, 610.2986084994358, 93.00338473110173, 21.806694245957146]
# bboxx [1426.100037608123, 610.7318540804813, 107.73373448664938, 23.395261376457256]
# bboxx [1449.062053403535, 637.304249717939, 144.55960887551714, 32.63783377209472]
# bboxx [1546.397893945092, 637.304249717939, 164.34449040992854, 33.64874012786754]
# bboxx [1508.561113200451, 610.8762692741631, 122.75291462955988, 23.97292215118466]
# bboxx [1592.033095148552, 611.3095148552086, 86.9379465964646, 21.951109439639026]
# bboxx [1645.1778864234673, 637.5930801053026, 99.64648364046616, 25.85031966904853]
# bboxx [0.0, 596.9409847514839, 1667.4566406704687, 26.14829472703991]
# bboxx [213.87964148527524, 617.5020370154812, 80.45629146781513, 5.363752764520996]
# bboxx [380.2667953023247, 611.2766470620976, 90.30223195235533, 5.69954915675612]
# bboxx [557.6652628063599, 604.1522106161524, 84.78079370674789, 6.233881890202042]
# bboxx [727.9392938644501, 603.0835451492605, 76.05335906046491, 2.84977457837806]
# bboxx [913.8688643050082, 601.8684513875745, 81.75765187619345, 2.807838549283474]
# bboxx [1082.3391772620132, 601.7032844140873, 86.54749410732393, 2.147170655334321]
# bboxx [1259.0678388933811, 603.0246202019854, 90.51150147101816, 3.4685064432323998]
# bboxx [1439.4301739414686, 605.1717908573197, 86.87782805429879, 2.6426715757961574]
# bboxx [1611.1733981288382, 605.5675665333766, 55.46903399850771, 2.3877398741079787]
# bboxx [1285.7648833599333, 584.533986313649, 47.22446927130022, 2.728524891230677]
# bboxx [1371.340176283859, 581.3306692018884, 40.68386535393711, 2.784447058444357]
# bboxx [1544.905130007027, 578.1770526675656, 37.1958747222277, 3.4643216653055333]
# bboxx [1125.8395656839034, 589.7474496741027, 45.50710247745951, 3.997245487884925]
# bboxx [1206.3994362858923, 587.1338660858702, 40.58741572313966, 3.228544432522426]
# bboxx [1016.06905497814, 574.2196883557804, 69.6443156158416, 3.0748042214499947]
# bboxx [1032.8267379850422, 565.763976746793, 41.5098569895747, 3.536024854667403]
# bboxx [1140.5165954650015, 559.9106145251396, 41.76930660532366, 2.6500164311534036]
# bboxx [914.8702519744264, 547.9112448288829, 28.30537796163958, 5.054531778864316]
# bboxx [904.472358029334, 541.8458066942459, 24.55058292591218, 4.765701391500556]
# bboxx [945.3418578412936, 541.8458066942459, 24.40616773222996, 4.6212861978186766]
# bboxx [960.649868371568, 547.044753666792, 24.117337344866428, 5.921022940955254]
# bboxx [1055.6750658142157, 545.4561865362917, 22.095524633320792, 5.776607747273374]
# bboxx [1073.1493042497175, 539.101918014291, 22.2399398270029, 6.2098533283189]
# bboxx [1097.8443023693117, 545.6006017299736, 28.883038736366643, 5.343362166227848]
# bboxx [1114.2714581924222, 540.5302316298357, 26.079146661935738, 4.5771563529111745]
# bboxx [1143.9697517380553, 545.4267244724848, 30.336966525108892, 5.535165822125123]
# bboxx [1155.1465288788847, 540.5302316298357, 28.52739308326045, 4.257819863173154]
# bboxx [1188.144632818477, 545.7460609622228, 36.08502334039258, 6.812511781077092]
# bboxx [1194.957144599554, 541.275350105891, 31.401421490902067, 3.8320378768559067]
# bboxx [1233.383968864692, 546.1718429485402, 36.40435983013094, 6.386729794759731]
# bboxx [1237.8546797210238, 540.2108951400977, 33.5303314224891, 5.002938339228422]
# bboxx [1277.2395134553758, 546.2782884451195, 39.810615720669375, 7.5576302571323595]
# bboxx [1277.345958951955, 540.317340636677, 35.87213234723413, 5.4287203255457825]
# bboxx [1322.2659585084325, 547.1298524177541, 42.258862141993404, 6.812511781077092]
# bboxx [1318.5403661281557, 540.4237861332564, 38.213933271979386, 6.812511781077092]
# bboxx [1369.7406499828132, 547.9814163903887, 36.72369631986885, 7.451184760553133]
# bboxx [1410.5092751726966, 548.4071983767061, 42.04597114883495, 7.87696674687038]
# bboxx [867.7627055072825, 547.9884621223622, 30.691468936139813, 5.82966449066339]
# bboxx [859.189669491601, 541.9873369113851, 28.97686173300349, 6.2583162914475]
# bboxx [817.6104448155456, 548.9314960840871, 36.94978522758731, 6.601237732074765]
# bboxx [815.2099947311549, 542.9303708731101, 32.834727940060134, 4.972360889095285]
# bboxx [772.0018932121201, 550.5603729270666, 35.49236910492141, 5.57247341019297]
# bboxx [774.0594218558836, 545.0736298770305, 30.862929656453503, 4.372248367997486]
# bboxx [727.079184489949, 551.6748676091053, 37.80708882915542, 5.743934130506545]
# bboxx [680.0132167638574, 553.2180140919279, 40.80765143464407, 5.486743050036125]
# bboxx [726.9077237696353, 545.5880120379713, 38.66439243072364, 6.086855571133924]
# bboxx [688.4147920592253, 547.131158520794, 39.52169603229174, 5.229551969565705]
# bboxx [634.6618562409022, 554.1610480536528, 42.7794497182507, 5.486743050036125]
# bboxx [643.4920833370542, 548.502844283303, 42.35079791746671, 6.772698452388454]
# bboxx [588.7103831968493, 550.3889122067529, 57.610802025379826, 10.802025379758788]
# bboxx [549.3601478848713, 551.2462158083212, 55.55327338161612, 11.230677180542784]
# bboxx [498.6077746720366, 552.0177890497325, 64.29777011761144, 12.34517186258131]
# bboxx [125.29644897894217, 553.7323962528687, 397.91593905810043, 20.6448619323063]
# bboxx [400.32123645730735, 595.0996287597545, 32.29335555723924, 3.491173573755532]
# bboxx [917.0597577452768, 504.0644801541035, 56.712229885888405, 13.917980432909246]
# bboxx [920.018015028326, 518.8328157963352, 34.58885438642244, 21.61803399151404]
# bboxx [941.8636072723824, 518.605257543793, 27.76210681015482, 22.528267001683048]
# bboxx [321.4999864524344, 536.3535372693526, 598.2604925894816, 16.907361747094]
# bboxx [810.0484239039685, 528.4550733779847, 29.744522161821124, 8.193101912836937]
# bboxx [676.3079013038406, 532.002421629284, 54.43350117389946, 9.639265832877982]
# bboxx [625.6257201684957, 537.1314154026331, 31.37195640265213, 5.440223653639123]
# bboxx [555.2654942480967, 538.9448232871795, 44.24715238293129, 6.165586807457657]
# bboxx [497.9618050964317, 541.4835943255443, 37.3562024216551, 4.1708381344566305]
# bboxx [1128.080461705678, 486.7382085942163, 72.74619965402667, 8.52379713117898]
# bboxx [1059.155274558731, 489.6774489842781, 20.57468273043196, 6.172404819129497]
# bboxx [916.8960396797452, 492.0288412963274, 58.931769820736804, 7.495062994657303]
# bboxx [797.8568038822466, 496.58466390092303, 44.52949190943457, 6.319366838632675]
# bboxx [697.3347825421366, 499.22998025197853, 74.5097438880639, 6.760252897141925]
# bboxx [695.6035439113717, 479.68633648921775, 38.660851328966714, 18.09036062185612]
# bboxx [791.6736377254244, 466.5253000797618, 219.25568546582872, 11.392331186895717]
# bboxx [1032.4066688714663, 467.459097718032, 135.96093613213247, 5.042507246658602]
# bboxx [1022.6951734334572, 418.9016205279847, 21.10382662490531, 47.81043907943115]
# bboxx [1048.841507305021, 427.1190397447619, 32.122638756492734, 40.15329844561603]
# bboxx [1088.808046222983, 441.126004318814, 30.815322062914447, 23.718460012061485]
# bboxx [1132.6965352216794, 448.5963854249751, 27.453650565142198, 18.675952765402826]
# bboxx [1332.0279863656165, 486.1631512852712, 77.74673876829229, 43.05594710269355]
# bboxx [208.4869815622125, 494.14870215574115, 408.1430228372594, 57.977042754869444]
# bboxx [769.6730786330357, 457.25125225999574, 7.9670411096949465, 14.795933489433594]
# bboxx [1158.5763452383403, 447.1281660243595, 12.662036559982198, 16.42107866372652]
# bboxx [1136.6156255796218, 437.6316386043731, 13.849102487480195, 15.827545699977293]
# bboxx [1097.8381386146773, 430.707087360633, 4.946108031243057, 11.67281495373328]
# bboxx [847.6117137136695, 424.5451145189324, 28.72544058436563, 24.289894611779744]
# bboxx [1501.8491341356023, 0.0, 418.1508658643977, 508.88171411799215]
# bboxx [1258.2720674315142, 0.0, 304.7904472020607, 334.46031374385376]
# bboxx [1136.4457972371804, 100.69772886911726, 122.2758136267853, 255.34066963240446]
# bboxx [1079.680226024978, 131.91639644267502, 54.554210678395975, 190.78562943461645]
# bboxx [1066.1187273252638, 160.88868911933727, 14.794362217870002, 162.12155263749312]
# bboxx [1057.4886826981729, 179.68985777121387, 8.938260506630058, 141.77930458792176]
# bboxx [0.0, 0.0, 418.6376360808707, 456.2612752721615]
# bboxx [411.47122861586297, 27.47122861586313, 213.95038576291984, 348.22530144004395]
# bboxx [623.2038072355956, 161.89992145266362, 81.61530286928792, 197.82839717229584]
# bboxx [623.647368664233, 106.89830430162174, 81.61530286928803, 88.7122857274869]
# bboxx [704.3755486762461, 52.34024857921728, 163.23060573857595, 318.477105761678]
# bboxx [863.8760833486998, 123.5626037248755, 16.994283606859653, 207.1178314586022]
# bboxx [861.7517978978424, 91.34427438687072, 48.858565369721646, 245.70901714917937]
# bboxx [908.8198915353142, 148.57759030795089, 17.354349687608988, 173.84795915131136]
# bboxx [926.1742412229232, 164.10516634423263, 19.790047889378798, 157.10253401414477]
# bboxx [945.3553645618596, 196.6826297929022, 18.267736513272666, 105.03948495131775]
# bboxx [958.5890896515948, 200.5152589262557, 25.396386271289202, 70.71150687300073]
# bboxx [983.4875075646232, 219.60404599291084, 34.85778507824, 50.6267830898245]
# bboxx [1019.3412293593844, 233.38117057145325, 36.683669058528494, 37.67960577504971]
# bboxx [1025.6488285640182, 276.20644938186217, 29.380133137373605, 37.01564796403562]
# info: 1
# images: 1
# annotations: 150
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 2
# new_annotations: 195
# new_categories: 3
#     Location:  ./
#  Output file:  custom_multy_coco_28_13_29_21.json

# %% [markdown]
# # MERGE MULTY JSON FILES INTO ONE

# %%
import datetime
import json
import os

data_path = './DATA/'
json_file = 'custom_multy_coco.json'
#new_json_path = './out/'
new_json_path = './'
file_format = '.json'
new_json_file = 'custom_multy_coco'

class JsonAnt:
    

    
        # LOAD DATA
    def __init__(self):
        
        self.createDict()

    def createDict(self):
        print('Creating dict')
        jsonAnt = {"info": [        {
            "contributor": "Konkuk_university",
            "date_created": "2021/05/21",
            "description": "PGON JSON file",
            "url": "",
            "version": "1.0",
            "year": 2021
        }],
           "images": [],
           "annotations": [],
           "categories": [
            {
                "id": 1,
                "name": "Building, Overpass, Bridge"
            },
            {
                "id": 2,
                "name": "Road Marking, Lane Marking"
            },
            {
                "id": 3,
                "name": "Guard Rail, Fence, Soundproof Wall"
            }]
          }
        return jsonAnt
        

    
    def write_json(self, jsonAnt, loaded_json, num_found_files):
        
        source_infos = loaded_json['info']
        source_images = loaded_json['images']
        source_categories = loaded_json['categories']
        source_annotations = loaded_json['annotations']
        
        
#         print('\n FILE < ' + str(num_found_files) + ' > details: ')
        source_infos_l = []
        source_infos_l.append(source_infos)
        print('info: ' + str(len(source_infos_l)))
        source_images_l = []
        source_images_l.append(source_images)
        print('images: ' + str(len(source_images_l)))
        print('annotations: ' + str(len(source_annotations)))
        print('categories: ' + str(len(source_categories)))

        file_desc = source_infos['description']
        print(f'file type is :{file_desc[33:47]}')
        
        
        new_source_infos = jsonAnt['info']
        new_source_images = jsonAnt['images']
        new_source_categories = jsonAnt['categories']
        new_source_annotations = jsonAnt['annotations']

        
        
#         new_source_infos.append(source_infos)
#         jsonAnt['info'] = new_source_infos
        new_source_images.append(source_images)
        jsonAnt['images'] = new_source_images
#         new_source_categories.append(source_categories)
#         jsonAnt['categories'] = new_source_categories
        for i in source_annotations:
            new_source_annotations.append(i)
        jsonAnt['annotations'] = new_source_annotations
        print('\n After merging the new file')
        print('new_info: ' + str(len(new_source_infos)))        
        print('new_images: ' + str(len(new_source_images)))
        print('new_annotations: ' + str(len(new_source_annotations)))
        print('new_categories: ' + str(len(new_source_categories)))
#         print('NEW jsonAnt: ' + str(jsonAnt))



        return jsonAnt

    
    
    
    def test(self):
        print('hello test')
        
        
        
# RUN THE PROGRAM
def main():
    
    callClass = JsonAnt()
    
    json_Ant  = callClass.createDict()
    
    num_found_files = []
    print(' Loading Coco json')
    for file in os.listdir(data_path):
        
        try:
            if 'json' in file:
                num_found_files =+ 1
                json_path = os.path.join(data_path, file)
                with open(json_path) as f:
                    loaded_json = json.load(f)
#                     print(f'loaded json11 {loaded_json}')
                print('\n  Loaded!')
                callClass.write_json(json_Ant, loaded_json, num_found_files)
#                 print('\n FILE < ' + str(num_found_files) + ' > details: ')
        except:
            if 'json' not in file:
                print(' Finished, nothing to load')
                return



    

    now = datetime.datetime.now()        # creating new file name with date attached
    currentDate = "_" + str(now.day) + "_" + str(now.hour) + "_" + str(now.minute) + "_" + str(now.second)
    file_output = os.path.join(new_json_file + currentDate + file_format)
    with open(new_json_path + file_output, 'a+') as outfile:
        json.dump(json_Ant, outfile, sort_keys=True, indent=4, )  # , indent=4, im.__dict__
        outfile.write('\n')
        outfile.close()
    print(f'    Location:  {new_json_path}  \n Output file:  {file_output} \n')
    
    
if __name__ == '__main__':
    main()
# Out:
# Creating dict
# Creating dict
#  Loading Coco json
#
#   Loaded!
# info: 1
# images: 1
# annotations: 45
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 1
# new_annotations: 45
# new_categories: 3
#
#   Loaded!
# info: 1
# images: 1
# annotations: 150
# categories: 3
# file type is :PGON JSON file
#
#  After merging the new file
# new_info: 1
# new_images: 2
# new_annotations: 195
# new_categories: 3
#     Location:  ./
#  Output file:  custom_multy_coco_28_13_20_28.json

# %%
#
